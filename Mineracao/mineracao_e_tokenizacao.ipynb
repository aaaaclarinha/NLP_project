# %%
# Importação de Bibliotecas 
import pandas as pd 
import spacy
import nltk
import matplotlib.pyplot as plt
import regex as re
from nltk.tokenize import TreebankWordTokenizer
from wordcloud import WordCloud
from collections import Counter

# Variáveis globais
t = TreebankWordTokenizer()
nlp = spacy.load('en_core_web_sm')

# %%
# Importando o dataset
df = pd.read_excel("df_completo.xlsx")

#df.columns

# %% [markdown]
# <h1> Seleção de artigos </h1>
#
# <p> Para iniciar a análise, vamos selecionar alguns artigos de interesse, para diminuir o número de dados e eliminar artigos desnecessários. Para isso, faremos uma filtragem com palavras-chave; 'alcohol', 'cancer', 'consumption' e 'ethanol'. Os artigos que não apresentarem as palavras-chave no abstract, não são considerados de interesse </p>

# %%
# Seleciona um grupo de artigos
artigos = df.iloc[0:100]

# Selecionando os abstracts dos artigos 
abs = artigos["Abstract"]

# Remove linhas com NaN
abstracts = abs.dropna()
index = abstracts.index

#print(artigos["Article Title"])

# %%
for texto, num in zip(abstracts, index):

    # Flags para indicar se as palavras-chave foram encontradas em algum artigo
    found_alcohol = False
    found_cancer = False
    found_consumption = False
    found_ethanol = False
    
    # Separa o texto em tooks
    tooks = nlp(texto)

    # Eliminar letras maiusculas (Case Folding)
    tooks_ = [t.lower_ for t in tooks]

    # Buscando as palavras-chave
    for took in tooks_:
        if took == "alcohol":
            found_alcohol = True
        if took == "cancer":
            found_cancer = True
        if took == "consumption":
            found_consumption = True
        if took == "ethanol":
            found_ethanol = True
        

    # Se todas as palavras-chave forem encontradas, este é um artigo de alto interesse 
    if found_alcohol and found_cancer and found_consumption and found_ethanol:
        print(f"O artigo {num} possuí todas as palavras-chave")

    # Verificar quais palavras-chave não foram encontradas e printar o número do artigo correspondente
    if not found_alcohol:
        print(f"A palavra 'alcohol' não foi encontrada no artigo {num}.")
    if not found_cancer:
        print(f"A palavra 'cancer' não foi encontrada no artigo {num}.")
    if not found_consumption:
        print(f"A palavra 'consumption' não foi encontrada no artigo {num}.")
    if not found_ethanol:
        print(f"A palavra 'ethanol' não foi encontrada no artigo {num}.")

    #print(contador)

    print()
# Out:
# A palavra 'alcohol' não foi encontrada no artigo 0.
# A palavra 'cancer' não foi encontrada no artigo 0.
# A palavra 'consumption' não foi encontrada no artigo 0.
# A palavra 'ethanol' não foi encontrada no artigo 0.
#
# A palavra 'alcohol' não foi encontrada no artigo 1.
# A palavra 'cancer' não foi encontrada no artigo 1.
# A palavra 'consumption' não foi encontrada no artigo 1.
# A palavra 'ethanol' não foi encontrada no artigo 1.
#
# A palavra 'ethanol' não foi encontrada no artigo 2.
#
# A palavra 'alcohol' não foi encontrada no artigo 3.
# A palavra 'cancer' não foi encontrada no artigo 3.
#
# A palavra 'cancer' não foi encontrada no artigo 4.
#
# A palavra 'alcohol' não foi encontrada no artigo 5.
# A palavra 'consumption' não foi encontrada no artigo 5.
# A palavra 'ethanol' não foi encontrada no artigo 5.
#
# A palavra 'cancer' não foi encontrada no artigo 6.
# A palavra 'consumption' não foi encontrada no artigo 6.
# A palavra 'ethanol' não foi encontrada no artigo 6.
#
# A palavra 'alcohol' não foi encontrada no artigo 7.
# A palavra 'cancer' não foi encontrada no artigo 7.
# A palavra 'consumption' não foi encontrada no artigo 7.
# A palavra 'ethanol' não foi encontrada no artigo 7.
#
# A palavra 'cancer' não foi encontrada no artigo 8.
# A palavra 'consumption' não foi encontrada no artigo 8.
# A palavra 'ethanol' não foi encontrada no artigo 8.
#
# A palavra 'alcohol' não foi encontrada no artigo 9.
# A palavra 'cancer' não foi encontrada no artigo 9.
# A palavra 'consumption' não foi encontrada no artigo 9.
# A palavra 'ethanol' não foi encontrada no artigo 9.
#
# A palavra 'alcohol' não foi encontrada no artigo 10.
# A palavra 'cancer' não foi encontrada no artigo 10.
# A palavra 'consumption' não foi encontrada no artigo 10.
# A palavra 'ethanol' não foi encontrada no artigo 10.
#
# A palavra 'alcohol' não foi encontrada no artigo 11.
# A palavra 'cancer' não foi encontrada no artigo 11.
# A palavra 'consumption' não foi encontrada no artigo 11.
# A palavra 'ethanol' não foi encontrada no artigo 11.
#
# A palavra 'alcohol' não foi encontrada no artigo 12.
# A palavra 'cancer' não foi encontrada no artigo 12.
# A palavra 'consumption' não foi encontrada no artigo 12.
# A palavra 'ethanol' não foi encontrada no artigo 12.
#
# A palavra 'cancer' não foi encontrada no artigo 13.
#
# A palavra 'alcohol' não foi encontrada no artigo 14.
# A palavra 'cancer' não foi encontrada no artigo 14.
# A palavra 'consumption' não foi encontrada no artigo 14.
# A palavra 'ethanol' não foi encontrada no artigo 14.
#
# A palavra 'alcohol' não foi encontrada no artigo 15.
# A palavra 'cancer' não foi encontrada no artigo 15.
# A palavra 'consumption' não foi encontrada no artigo 15.
# A palavra 'ethanol' não foi encontrada no artigo 15.
#
# A palavra 'alcohol' não foi encontrada no artigo 16.
# A palavra 'cancer' não foi encontrada no artigo 16.
# A palavra 'consumption' não foi encontrada no artigo 16.
# A palavra 'ethanol' não foi encontrada no artigo 16.
#
# A palavra 'alcohol' não foi encontrada no artigo 17.
# A palavra 'cancer' não foi encontrada no artigo 17.
# A palavra 'consumption' não foi encontrada no artigo 17.
# A palavra 'ethanol' não foi encontrada no artigo 17.
#
# A palavra 'cancer' não foi encontrada no artigo 18.
# A palavra 'ethanol' não foi encontrada no artigo 18.
#
# A palavra 'cancer' não foi encontrada no artigo 19.
# A palavra 'consumption' não foi encontrada no artigo 19.
#
# A palavra 'alcohol' não foi encontrada no artigo 20.
# A palavra 'cancer' não foi encontrada no artigo 20.
#
# A palavra 'alcohol' não foi encontrada no artigo 21.
# A palavra 'cancer' não foi encontrada no artigo 21.
# A palavra 'consumption' não foi encontrada no artigo 21.
# A palavra 'ethanol' não foi encontrada no artigo 21.
#
# A palavra 'alcohol' não foi encontrada no artigo 22.
# A palavra 'cancer' não foi encontrada no artigo 22.
# A palavra 'consumption' não foi encontrada no artigo 22.
# A palavra 'ethanol' não foi encontrada no artigo 22.
#
# A palavra 'cancer' não foi encontrada no artigo 23.
# A palavra 'ethanol' não foi encontrada no artigo 23.
#
# A palavra 'alcohol' não foi encontrada no artigo 24.
# A palavra 'ethanol' não foi encontrada no artigo 24.
#
# A palavra 'alcohol' não foi encontrada no artigo 25.
#
# A palavra 'alcohol' não foi encontrada no artigo 26.
# A palavra 'cancer' não foi encontrada no artigo 26.
# A palavra 'consumption' não foi encontrada no artigo 26.
# A palavra 'ethanol' não foi encontrada no artigo 26.
#
# A palavra 'alcohol' não foi encontrada no artigo 28.
# A palavra 'cancer' não foi encontrada no artigo 28.
# A palavra 'consumption' não foi encontrada no artigo 28.
# A palavra 'ethanol' não foi encontrada no artigo 28.
#
# A palavra 'alcohol' não foi encontrada no artigo 29.
# A palavra 'consumption' não foi encontrada no artigo 29.
# A palavra 'ethanol' não foi encontrada no artigo 29.
#
# A palavra 'alcohol' não foi encontrada no artigo 30.
# A palavra 'cancer' não foi encontrada no artigo 30.
# A palavra 'ethanol' não foi encontrada no artigo 30.
#
# A palavra 'alcohol' não foi encontrada no artigo 31.
# A palavra 'cancer' não foi encontrada no artigo 31.
# A palavra 'consumption' não foi encontrada no artigo 31.
# A palavra 'ethanol' não foi encontrada no artigo 31.
#
# A palavra 'cancer' não foi encontrada no artigo 32.
# A palavra 'consumption' não foi encontrada no artigo 32.
# A palavra 'ethanol' não foi encontrada no artigo 32.
#
# A palavra 'alcohol' não foi encontrada no artigo 33.
# A palavra 'cancer' não foi encontrada no artigo 33.
# A palavra 'consumption' não foi encontrada no artigo 33.
# A palavra 'ethanol' não foi encontrada no artigo 33.
#
# A palavra 'alcohol' não foi encontrada no artigo 34.
# A palavra 'cancer' não foi encontrada no artigo 34.
# A palavra 'consumption' não foi encontrada no artigo 34.
# A palavra 'ethanol' não foi encontrada no artigo 34.
#
# A palavra 'cancer' não foi encontrada no artigo 35.
# A palavra 'ethanol' não foi encontrada no artigo 35.
#
# A palavra 'alcohol' não foi encontrada no artigo 36.
# A palavra 'cancer' não foi encontrada no artigo 36.
# A palavra 'consumption' não foi encontrada no artigo 36.
# A palavra 'ethanol' não foi encontrada no artigo 36.
#
# A palavra 'alcohol' não foi encontrada no artigo 37.
# A palavra 'cancer' não foi encontrada no artigo 37.
# A palavra 'consumption' não foi encontrada no artigo 37.
# A palavra 'ethanol' não foi encontrada no artigo 37.
#
# A palavra 'alcohol' não foi encontrada no artigo 38.
# A palavra 'cancer' não foi encontrada no artigo 38.
# A palavra 'consumption' não foi encontrada no artigo 38.
# A palavra 'ethanol' não foi encontrada no artigo 38.
#
# A palavra 'alcohol' não foi encontrada no artigo 39.
# A palavra 'cancer' não foi encontrada no artigo 39.
# A palavra 'consumption' não foi encontrada no artigo 39.
# A palavra 'ethanol' não foi encontrada no artigo 39.
#
# A palavra 'alcohol' não foi encontrada no artigo 40.
# A palavra 'cancer' não foi encontrada no artigo 40.
# A palavra 'consumption' não foi encontrada no artigo 40.
# A palavra 'ethanol' não foi encontrada no artigo 40.
#
# A palavra 'cancer' não foi encontrada no artigo 41.
# A palavra 'consumption' não foi encontrada no artigo 41.
# A palavra 'ethanol' não foi encontrada no artigo 41.
#
# A palavra 'alcohol' não foi encontrada no artigo 42.
# A palavra 'cancer' não foi encontrada no artigo 42.
# A palavra 'consumption' não foi encontrada no artigo 42.
# A palavra 'ethanol' não foi encontrada no artigo 42.
#
# A palavra 'cancer' não foi encontrada no artigo 43.
# A palavra 'consumption' não foi encontrada no artigo 43.
# A palavra 'ethanol' não foi encontrada no artigo 43.
#
# A palavra 'alcohol' não foi encontrada no artigo 44.
# A palavra 'cancer' não foi encontrada no artigo 44.
# A palavra 'consumption' não foi encontrada no artigo 44.
# A palavra 'ethanol' não foi encontrada no artigo 44.
#
# A palavra 'alcohol' não foi encontrada no artigo 45.
# A palavra 'cancer' não foi encontrada no artigo 45.
# A palavra 'consumption' não foi encontrada no artigo 45.
# A palavra 'ethanol' não foi encontrada no artigo 45.
#
# A palavra 'alcohol' não foi encontrada no artigo 46.
# A palavra 'cancer' não foi encontrada no artigo 46.
# A palavra 'consumption' não foi encontrada no artigo 46.
# A palavra 'ethanol' não foi encontrada no artigo 46.
#
# A palavra 'cancer' não foi encontrada no artigo 47.
# A palavra 'consumption' não foi encontrada no artigo 47.
# A palavra 'ethanol' não foi encontrada no artigo 47.
#
# A palavra 'consumption' não foi encontrada no artigo 49.
# A palavra 'ethanol' não foi encontrada no artigo 49.
#
# A palavra 'alcohol' não foi encontrada no artigo 50.
# A palavra 'cancer' não foi encontrada no artigo 50.
# A palavra 'consumption' não foi encontrada no artigo 50.
# A palavra 'ethanol' não foi encontrada no artigo 50.
#
# A palavra 'cancer' não foi encontrada no artigo 51.
# A palavra 'consumption' não foi encontrada no artigo 51.
# A palavra 'ethanol' não foi encontrada no artigo 51.
#
# A palavra 'cancer' não foi encontrada no artigo 52.
# A palavra 'consumption' não foi encontrada no artigo 52.
# A palavra 'ethanol' não foi encontrada no artigo 52.
#
# A palavra 'alcohol' não foi encontrada no artigo 53.
# A palavra 'cancer' não foi encontrada no artigo 53.
# A palavra 'consumption' não foi encontrada no artigo 53.
# A palavra 'ethanol' não foi encontrada no artigo 53.
#
# A palavra 'cancer' não foi encontrada no artigo 54.
# A palavra 'ethanol' não foi encontrada no artigo 54.
#
# A palavra 'alcohol' não foi encontrada no artigo 55.
# A palavra 'cancer' não foi encontrada no artigo 55.
# A palavra 'consumption' não foi encontrada no artigo 55.
# A palavra 'ethanol' não foi encontrada no artigo 55.
#
# A palavra 'cancer' não foi encontrada no artigo 57.
# A palavra 'ethanol' não foi encontrada no artigo 57.
#
# A palavra 'alcohol' não foi encontrada no artigo 58.
# A palavra 'cancer' não foi encontrada no artigo 58.
# A palavra 'ethanol' não foi encontrada no artigo 58.
#
# A palavra 'cancer' não foi encontrada no artigo 60.
# A palavra 'consumption' não foi encontrada no artigo 60.
# A palavra 'ethanol' não foi encontrada no artigo 60.
#
# A palavra 'alcohol' não foi encontrada no artigo 61.
# A palavra 'cancer' não foi encontrada no artigo 61.
# A palavra 'consumption' não foi encontrada no artigo 61.
# A palavra 'ethanol' não foi encontrada no artigo 61.
#
# A palavra 'cancer' não foi encontrada no artigo 62.
# A palavra 'consumption' não foi encontrada no artigo 62.
# A palavra 'ethanol' não foi encontrada no artigo 62.
#
# A palavra 'cancer' não foi encontrada no artigo 63.
# A palavra 'ethanol' não foi encontrada no artigo 63.
#
# A palavra 'alcohol' não foi encontrada no artigo 64.
# A palavra 'cancer' não foi encontrada no artigo 64.
# A palavra 'consumption' não foi encontrada no artigo 64.
# A palavra 'ethanol' não foi encontrada no artigo 64.
#
# A palavra 'cancer' não foi encontrada no artigo 65.
# A palavra 'ethanol' não foi encontrada no artigo 65.
#
# A palavra 'alcohol' não foi encontrada no artigo 66.
# A palavra 'cancer' não foi encontrada no artigo 66.
# A palavra 'consumption' não foi encontrada no artigo 66.
# A palavra 'ethanol' não foi encontrada no artigo 66.
#
# A palavra 'alcohol' não foi encontrada no artigo 67.
# A palavra 'cancer' não foi encontrada no artigo 67.
# A palavra 'consumption' não foi encontrada no artigo 67.
# A palavra 'ethanol' não foi encontrada no artigo 67.
#
# A palavra 'cancer' não foi encontrada no artigo 68.
# A palavra 'ethanol' não foi encontrada no artigo 68.
#
# A palavra 'alcohol' não foi encontrada no artigo 69.
# A palavra 'cancer' não foi encontrada no artigo 69.
# A palavra 'consumption' não foi encontrada no artigo 69.
# A palavra 'ethanol' não foi encontrada no artigo 69.
#
# A palavra 'cancer' não foi encontrada no artigo 70.
# A palavra 'consumption' não foi encontrada no artigo 70.
# A palavra 'ethanol' não foi encontrada no artigo 70.
#
# A palavra 'consumption' não foi encontrada no artigo 71.
# A palavra 'ethanol' não foi encontrada no artigo 71.
#
# A palavra 'alcohol' não foi encontrada no artigo 72.
# A palavra 'cancer' não foi encontrada no artigo 72.
# A palavra 'consumption' não foi encontrada no artigo 72.
# A palavra 'ethanol' não foi encontrada no artigo 72.
#
# A palavra 'cancer' não foi encontrada no artigo 73.
# A palavra 'consumption' não foi encontrada no artigo 73.
# A palavra 'ethanol' não foi encontrada no artigo 73.
#
# A palavra 'alcohol' não foi encontrada no artigo 74.
# A palavra 'cancer' não foi encontrada no artigo 74.
# A palavra 'consumption' não foi encontrada no artigo 74.
#
# A palavra 'alcohol' não foi encontrada no artigo 75.
# A palavra 'cancer' não foi encontrada no artigo 75.
# A palavra 'consumption' não foi encontrada no artigo 75.
# A palavra 'ethanol' não foi encontrada no artigo 75.
#
# A palavra 'alcohol' não foi encontrada no artigo 76.
# A palavra 'cancer' não foi encontrada no artigo 76.
# A palavra 'consumption' não foi encontrada no artigo 76.
# A palavra 'ethanol' não foi encontrada no artigo 76.
#
# A palavra 'alcohol' não foi encontrada no artigo 77.
# A palavra 'cancer' não foi encontrada no artigo 77.
# A palavra 'consumption' não foi encontrada no artigo 77.
# A palavra 'ethanol' não foi encontrada no artigo 77.
#
# A palavra 'alcohol' não foi encontrada no artigo 78.
# A palavra 'cancer' não foi encontrada no artigo 78.
# A palavra 'ethanol' não foi encontrada no artigo 78.
#
# A palavra 'cancer' não foi encontrada no artigo 79.
# A palavra 'consumption' não foi encontrada no artigo 79.
# A palavra 'ethanol' não foi encontrada no artigo 79.
#
# A palavra 'alcohol' não foi encontrada no artigo 80.
# A palavra 'cancer' não foi encontrada no artigo 80.
# A palavra 'consumption' não foi encontrada no artigo 80.
#
# A palavra 'alcohol' não foi encontrada no artigo 81.
# A palavra 'cancer' não foi encontrada no artigo 81.
# A palavra 'consumption' não foi encontrada no artigo 81.
# A palavra 'ethanol' não foi encontrada no artigo 81.
#
# A palavra 'cancer' não foi encontrada no artigo 82.
# A palavra 'consumption' não foi encontrada no artigo 82.
# A palavra 'ethanol' não foi encontrada no artigo 82.
#
# A palavra 'consumption' não foi encontrada no artigo 83.
# A palavra 'ethanol' não foi encontrada no artigo 83.
#
# A palavra 'alcohol' não foi encontrada no artigo 84.
# A palavra 'cancer' não foi encontrada no artigo 84.
# A palavra 'consumption' não foi encontrada no artigo 84.
# A palavra 'ethanol' não foi encontrada no artigo 84.
#
# A palavra 'alcohol' não foi encontrada no artigo 85.
# A palavra 'cancer' não foi encontrada no artigo 85.
# A palavra 'consumption' não foi encontrada no artigo 85.
# A palavra 'ethanol' não foi encontrada no artigo 85.
#
# A palavra 'cancer' não foi encontrada no artigo 86.
# A palavra 'consumption' não foi encontrada no artigo 86.
# A palavra 'ethanol' não foi encontrada no artigo 86.
#
# A palavra 'alcohol' não foi encontrada no artigo 87.
# A palavra 'cancer' não foi encontrada no artigo 87.
# A palavra 'consumption' não foi encontrada no artigo 87.
# A palavra 'ethanol' não foi encontrada no artigo 87.
#
# A palavra 'alcohol' não foi encontrada no artigo 88.
# A palavra 'cancer' não foi encontrada no artigo 88.
# A palavra 'consumption' não foi encontrada no artigo 88.
#
# A palavra 'cancer' não foi encontrada no artigo 90.
# A palavra 'ethanol' não foi encontrada no artigo 90.
#
# A palavra 'alcohol' não foi encontrada no artigo 91.
# A palavra 'cancer' não foi encontrada no artigo 91.
# A palavra 'consumption' não foi encontrada no artigo 91.
# A palavra 'ethanol' não foi encontrada no artigo 91.
#
# A palavra 'alcohol' não foi encontrada no artigo 92.
# A palavra 'cancer' não foi encontrada no artigo 92.
# A palavra 'consumption' não foi encontrada no artigo 92.
# A palavra 'ethanol' não foi encontrada no artigo 92.
#
# A palavra 'alcohol' não foi encontrada no artigo 93.
# A palavra 'cancer' não foi encontrada no artigo 93.
# A palavra 'consumption' não foi encontrada no artigo 93.
# A palavra 'ethanol' não foi encontrada no artigo 93.
#
# A palavra 'cancer' não foi encontrada no artigo 94.
# A palavra 'consumption' não foi encontrada no artigo 94.
#
# A palavra 'alcohol' não foi encontrada no artigo 95.
# A palavra 'cancer' não foi encontrada no artigo 95.
# A palavra 'consumption' não foi encontrada no artigo 95.
# A palavra 'ethanol' não foi encontrada no artigo 95.
#
# A palavra 'alcohol' não foi encontrada no artigo 96.
# A palavra 'cancer' não foi encontrada no artigo 96.
# A palavra 'consumption' não foi encontrada no artigo 96.
# A palavra 'ethanol' não foi encontrada no artigo 96.
#
# A palavra 'cancer' não foi encontrada no artigo 97.
# A palavra 'consumption' não foi encontrada no artigo 97.
# A palavra 'ethanol' não foi encontrada no artigo 97.
#
# A palavra 'cancer' não foi encontrada no artigo 98.
# A palavra 'ethanol' não foi encontrada no artigo 98.
#
# A palavra 'alcohol' não foi encontrada no artigo 99.
# A palavra 'cancer' não foi encontrada no artigo 99.
# A palavra 'consumption' não foi encontrada no artigo 99.
# A palavra 'ethanol' não foi encontrada no artigo 99.

# %% [markdown]
# <h1> Pré-processamento dos textos </h1>
#
# <p> Foram selecionados os artigos com base nas palavra-chave. Agora, faremos um pré-processamento para entender como eles apresentam os temas de interesse </p>

# %%
# Artigos relacionados
lista = [2, 25, 49, 71, 83, 134, 596, 1014, 1421, 1438, 1441, 1578, 1591, 1866]

artigos = df["Abstract"][lista]

# %%
# Tokenização dos textos

palavras = []

for texto in artigos:

    # Eliminar letras maiusculas (Case Folding)
    txt = texto.lower()

    # Separa o texto em tokens
    toks = nlp(txt)

    # Remover stop_words
    w = [t for t in toks if not t.is_stop] 

    # Remove pontuações
    w = [token.text for token in w if not token.is_punct]
    
    # Transforma os tokens em string
    string = [str(word) for word in w]

    # Junta as strings em uma sentença
    string_resultante = ' '.join(string)
    
    # Armazena a sentença em uma lista 
    palavras.append(string_resultante)

# Junta todas as sentenças da lista em uma
texto = ' '.join(palavras)

# Remove sinais matemáticos 
texto = re.sub(r'[+\-*/=]', '', texto)

#texto

# %%
# Criar uma WordCloud 
wordcloud = WordCloud(width=3000, height=2000, background_color='white', max_words=100, stopwords=None).generate(texto)

# Exibir WordClound
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Criar uma WordCloud (considerando palavras soltas, sem colocações)
wordcloud = WordCloud(width=3000, height=2000, background_color='white', max_words=100, stopwords=None, collocations=False).generate(texto)

# Exibir WordClound
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Verificar a contagem de palavras
contagem_palavras = Counter(texto.split())

contagem_palavras
# Out:
# Counter({'cancer': 76,
#          'risk': 72,
#          'alcohol': 68,
#          'consumption': 60,
#          'associated': 32,
#          '95': 29,
#          'health': 26,
#          'ci': 26,
#          'states': 25,
#          'factors': 24,
#          'mmsa': 23,
#          'territories': 22,
#          'results': 22,
#          'adults': 21,
#          'years': 19,
#          'diabetes': 18,
#          'mortality': 18,
#          'lifestyle': 18,
#          'gastric': 18,
#          'liver': 17,
#          'hypertension': 16,
#          'cohort': 16,
#          'abnormal': 16,
#          'diseases': 15,
#          'study': 14,
#          'drinkers': 14,
#          'aged': 13,
#          '>': 13,
#          'women': 13,
#          'low': 13,
#          'lft': 13,
#          'prostate': 13,
#          'breast': 13,
#          'disease': 12,
#          'light': 12,
#          'increased': 12,
#          'analysis': 12,
#          'drinking': 11,
#          'healthy': 11,
#          'compared': 11,
#          'diagnosis': 11,
#          'microvascular': 11,
#          'complications': 11,
#          'conditions': 10,
#          'population': 10,
#          'intake': 10,
#          'g': 10,
#          'association': 10,
#          'cases': 10,
#          'lower': 10,
#          'relationship': 10,
#          'diabetic': 10,
#          'studies': 10,
#          'renal': 10,
#          'use': 9,
#          'blood': 9,
#          'data': 9,
#          'estimates': 9,
#          'reported': 9,
#          'total': 9,
#          'included': 9,
#          'specific': 9,
#          'moderate': 9,
#          'meta': 9,
#          'chronic': 8,
#          'care': 8,
#          '25': 8,
#          'dose': 8,
#          'incidence': 8,
#          'd': 8,
#          'heavy': 8,
#          'behaviors': 7,
#          'age': 7,
#          'adjusted': 7,
#          'current': 7,
#          'dietary': 7,
#          '4': 7,
#          'week': 7,
#          'significantly': 7,
#          'participants': 7,
#          'prospective': 7,
#          'incident': 7,
#          'risks': 7,
#          'patients': 7,
#          '2': 7,
#          'lung': 7,
#          'recurrence': 7,
#          'reporting': 6,
#          'smokers': 6,
#          'binge': 6,
#          '45': 6,
#          'high': 6,
#          'test': 6,
#          '3': 6,
#          'findings': 6,
#          'polyphenols': 6,
#          'urine': 6,
#          'significant': 6,
#          'observed': 6,
#          '5': 6,
#          'follow': 6,
#          'confidence': 6,
#          'fatty': 6,
#          'men': 6,
#          'analyses': 6,
#          'non': 6,
#          'associations': 6,
#          'effect': 6,
#          'diet': 5,
#          'pressure': 5,
#          'preventive': 5,
#          'factor': 5,
#          'brfss': 5,
#          'state': 5,
#          'prevalence': 5,
#          'design': 5,
#          'present': 5,
#          'different': 5,
#          'serum': 5,
#          'concentrations': 5,
#          'identified': 5,
#          '<': 5,
#          'body': 5,
#          'index': 5,
#          'hazard': 5,
#          'large': 5,
#          'lfts': 5,
#          'evidence': 5,
#          'questionnaires': 5,
#          'neuropathy': 5,
#          'hr': 5,
#          'found': 5,
#          'response': 5,
#          'cancers': 5,
#          'causes': 4,
#          'morbidity': 4,
#          'physical': 4,
#          'levels': 4,
#          'access': 4,
#          'services': 4,
#          'public': 4,
#          'important': 4,
#          'information': 4,
#          'period': 4,
#          'based': 4,
#          'status': 4,
#          'cardiovascular': 4,
#          'measures': 4,
#          'following': 4,
#          'past': 4,
#          'month': 4,
#          'evaluate': 4,
#          'objective': 4,
#          'trans': 4,
#          'resveratrol': 4,
#          'catechin': 4,
#          'quercetin': 4,
#          '10': 4,
#          'intervals': 4,
#          'time': 4,
#          '24': 4,
#          'free': 4,
#          'peak': 4,
#          'h': 4,
#          'excretion': 4,
#          'effects': 4,
#          'higher': 4,
#          'conclusions': 4,
#          '40': 4,
#          'assessed': 4,
#          '6': 4,
#          'mass': 4,
#          'bmi': 4,
#          'interval': 4,
#          'ard': 4,
#          '1000': 4,
#          'person': 4,
#          'adherence': 4,
#          'potential': 4,
#          'primary': 4,
#          'investigated': 4,
#          'followed': 4,
#          'panel': 4,
#          '1': 4,
#          'alt': 4,
#          'small': 4,
#          'loss': 4,
#          'remains': 4,
#          'weight': 4,
#          'overall': 4,
#          'type': 4,
#          'disorders': 4,
#          'conducted': 4,
#          'p': 4,
#          'showed': 4,
#          'e.g.': 3,
#          'heart': 3,
#          'arthritis': 3,
#          'leading': 3,
#          'united': 3,
#          'frequent': 3,
#          'distress': 3,
#          'sleep': 3,
#          'adopting': 3,
#          'positive': 3,
#          'provide': 3,
#          '2013': 3,
#          '2014': 3,
#          'random': 3,
#          'practices': 3,
#          'report': 3,
#          'inadequate': 3,
#          'having': 3,
#          'obesity': 3,
#          'colorectal': 3,
#          'certain': 3,
#          'need': 3,
#          'local': 3,
#          'identify': 3,
#          'powerful': 3,
#          'vitro': 3,
#          'subjects': 3,
#          'mg70': 3,
#          'kg': 3,
#          'ethanol': 3,
#          'collected': 3,
#          'zero': 3,
#          '30': 3,
#          'consumed': 3,
#          'activity': 3,
#          'modifiable': 3,
#          'combined': 3,
#          'hypothetical': 3,
#          'setting': 3,
#          'normal': 3,
#          '14': 3,
#          'vigorous': 3,
#          'developing': 3,
#          'analyzed': 3,
#          'main': 3,
#          'self': 3,
#          'history': 3,
#          'ratio': 3,
#          'greater': 3,
#          'people': 3,
#          'early': 3,
#          'analytes': 3,
#          'genetic': 3,
#          'diagnostic': 3,
#          'alp': 3,
#          'including': 3,
#          'retinopathy': 3,
#          'nephropathy': 3,
#          'foot': 3,
#          '0.91': 3,
#          'suggest': 3,
#          'patterns': 3,
#          'twin': 3,
#          'cox': 3,
#          'performed': 3,
#          'environmental': 3,
#          '1.04': 3,
#          'conclusion': 3,
#          'baseline': 3,
#          'trend': 3,
#          'inversely': 3,
#          'subsites': 3,
#          'review': 3,
#          'types': 3,
#          'stroke': 2,
#          'u.s': 2,
#          'preventable': 2,
#          'behavioral': 2,
#          'excessive': 2,
#          'tobacco': 2,
#          'mental': 2,
#          'cholesterol': 2,
#          'reduce': 2,
#          'monitoring': 2,
#          'points': 2,
#          'statistical': 2,
#          'development': 2,
#          'programs': 2,
#          'system': 2,
#          'survey': 2,
#          '18': 2,
#          'death': 2,
#          'include': 2,
#          'presented': 2,
#          '50': 2,
#          'selected': 2,
#          'range': 2,
#          'identifying': 2,
#          'form': 2,
#          'coronary': 2,
#          '2008': 2,
#          'highlight': 2,
#          'action': 2,
#          'background': 2,
#          'despite': 2,
#          'biologic': 2,
#          'constituents': 2,
#          'wine': 2,
#          'given': 2,
#          'orally': 2,
#          'human': 2,
#          'randomly': 2,
#          'groups': 2,
#          'consuming': 2,
#          'polyphenol': 2,
#          'administered': 2,
#          'matrices': 2,
#          'white': 2,
#          'juice': 2,
#          'conjugates': 2,
#          'absorption': 2,
#          'efficient': 2,
#          'matrix': 2,
#          'l': 2,
#          'consistent': 2,
#          'clinical': 2,
#          'estimate': 2,
#          'nurses': 2,
#          'mm': 2,
#          'hg': 2,
#          '2005': 2,
#          'daily': 2,
#          'mean': 2,
#          'minutes': 2,
#          'exercise': 2,
#          'stop': 2,
#          'dash': 2,
#          'questionnaire': 2,
#          'modest': 2,
#          'nonnarcotic': 2,
#          'analgesics': 2,
#          '400': 2,
#          'mu': 2,
#          'folic': 2,
#          'acid': 2,
#          'plus': 2,
#          'outcome': 2,
#          'ratios': 2,
#          'pars': 2,
#          'adjusting': 2,
#          '0.51': 2,
#          'par': 2,
#          'rate': 2,
#          'new': 2,
#          'onset': 2,
#          'known': 2,
#          'testing': 2,
#          'pre': 2,
#          'tests': 2,
#          'features': 2,
#          'viral': 2,
#          'cirrhosis': 2,
#          'ggt': 2,
#          'repeating': 2,
#          'nearly': 2,
#          'fat': 2,
#          'anxiety': 2,
#          'sustained': 2,
#          'little': 2,
#          'particular': 2,
#          'purpose': 2,
#          'term': 2,
#          'future': 2,
#          'evaluated': 2,
#          'importance': 2,
#          'subsequent': 2,
#          'unclear': 2,
#          '2000': 2,
#          'april': 2,
#          'validated': 2,
#          'relative': 2,
#          'rr': 2,
#          '0.60': 2,
#          '0.57': 2,
#          '1.00': 2,
#          'similar': 2,
#          '0.55': 2,
#          '0.86': 2,
#          '0.98': 2,
#          '0.62': 2,
#          '1.05': 2,
#          'increment': 2,
#          '0.90': 2,
#          'individuals': 2,
#          'older': 2,
#          'post': 2,
#          'average': 2,
#          'regular': 2,
#          'epidemiologic': 2,
#          'aimed': 2,
#          'investigate': 2,
#          'finnish': 2,
#          'twins': 2,
#          'methods': 2,
#          'regression': 2,
#          'co': 2,
#          'drinks': 2,
#          '1.46': 2,
#          'fold': 2,
#          '1.12': 2,
#          '1.90': 2,
#          'independent': 2,
#          '450': 2,
#          'nonsmokers': 2,
#          'proportional': 2,
#          'multivariate': 2,
#          'hrs': 2,
#          'highest': 2,
#          'category': 2,
#          '1.30': 2,
#          'pubmed': 2,
#          'embase': 2,
#          'searched': 2,
#          'cis': 2,
#          'summary': 2,
#          'subgroup': 2,
#          'indicated': 2,
#          'country': 2,
#          'models': 2,
#          'i2': 2,
#          '1.02': 2,
#          'european': 2,
#          'lifetime': 2,
#          'increasing': 2,
#          'versus': 2,
#          '0.99': 2,
#          'parenchyma': 2,
#          'objectives': 2,
#          'research': 2,
#          'contribute': 2,
#          'comprehensive': 2,
#          'systematic': 2,
#          'find': 2,
#          'esophageal': 2,
#          'survival': 2,
#          '20': 2,
#          'skin': 2,
#          'melanoma': 2,
#          'problem': 1,
#          'costly': 1,
#          'economy': 1,
#          'controllable': 1,
#          'poor': 1,
#          'insufficient': 1,
#          'linked': 1,
#          'staying': 1,
#          'physically': 1,
#          'active': 1,
#          'quitting': 1,
#          'obtaining': 1,
#          'routine': 1,
#          'checkups': 1,
#          'checking': 1,
#          'multilevel': 1,
#          'metropolitan': 1,
#          'micropolitan': 1,
#          'areas': 1,
#          'evaluation': 1,
#          'intervention': 1,
#          'description': 1,
#          'surveillance': 1,
#          'ongoing': 1,
#          'digitdialed': 1,
#          'telephone': 1,
#          'noninstitutionalized': 1,
#          'residing': 1,
#          'collects': 1,
#          'related': 1,
#          'disability': 1,
#          'participating': 1,
#          'district': 1,
#          'columbia': 1,
#          'commonwealth': 1,
#          'puerto': 1,
#          'rico': 1,
#          'guam': 1,
#          'indicators': 1,
#          'vary': 1,
#          'territory': 1,
#          'set': 1,
#          'proportions': 1,
#          'refers': 1,
#          'respondents': 1,
#          '7.7%15.2': 1,
#          '6.3%19.4': 1,
#          '27.6%49.2': 1,
#          '26.5%44.4': 1,
#          '64': 1,
#          'coverage': 1,
#          '66.9%92.4': 1,
#          '60.5%97.6': 1,
#          'cigarette': 1,
#          '10.1%28.8': 1,
#          '6.1%33.6': 1,
#          '10.5%25.2': 1,
#          '7.2%25.3': 1,
#          '21.0%35.2': 1,
#          '12.1%37.1': 1,
#          '30.6%51.0': 1,
#          '27.6%52.4': 1,
#          '7.4%17.5': 1,
#          '6.2%20.9': 1,
#          '3.1%7.5': 1,
#          '2.3%9.4': 1,
#          '25.2%40.1': 1,
#          '22.2%42.2': 1,
#          '28.8%38.4': 1,
#          '26.3%39.6': 1,
#          '7.8%16.0': 1,
#          '6.2%18.5': 1,
#          '21': 1,
#          '65': 1,
#          'papanicolaou': 1,
#          '67.7%87.8': 1,
#          '68.0%94.3': 1,
#          '75': 1,
#          'received': 1,
#          'screening': 1,
#          'basis': 1,
#          'task': 1,
#          'force': 1,
#          'recommendation': 1,
#          '42.8%76.7': 1,
#          '49.1%79.6': 1,
#          '28.4%48.6': 1,
#          '25.4%45.3': 1,
#          '10.7%25.1': 1,
#          '6.7%26.3': 1,
#          '8.0%17.1': 1,
#          '7.6%19.2': 1,
#          '31.2%54.7': 1,
#          '28.4%54.7': 1,
#          '21.0%35.9': 1,
#          '19.7%42.5': 1,
#          'interpretation': 1,
#          'varies': 1,
#          'continued': 1,
#          'departments': 1,
#          'agencies': 1,
#          'continue': 1,
#          'populations': 1,
#          'unhealthy': 1,
#          'monitor': 1,
#          'activities': 1,
#          'conducive': 1,
#          'protection': 1,
#          'atherosclerosis': 1,
#          'inflammatory': 1,
#          'demonstrated': 1,
#          'considerable': 1,
#          'doubt': 1,
#          'polyphenolic': 1,
#          'red': 1,
#          'components': 1,
#          'effective': 1,
#          'vivo': 1,
#          'tested': 1,
#          'absorptive': 1,
#          'efficiency': 1,
#          'media': 1,
#          'males': 1,
#          'assigned': 1,
#          '11.5': 1,
#          'grape': 1,
#          'vegetable': 1,
#          'homogenate': 1,
#          'hours': 1,
#          'h.': 1,
#          'sums': 1,
#          'conjugated': 1,
#          'measured': 1,
#          'gas': 1,
#          'chromatographic': 1,
#          'method': 1,
#          'predominantly': 1,
#          'glucuronide': 1,
#          'sulfate': 1,
#          'reaching': 1,
#          'min': 1,
#          'accounted': 1,
#          '1.7': 1,
#          '1.9': 1,
#          '1.1': 1,
#          '6.5': 1,
#          '17.2': 1,
#          '26.9': 1,
#          'judged': 1,
#          'concentration': 1,
#          'area': 1,
#          'curve': 1,
#          'urinary': 1,
#          '16': 1,
#          '17': 1,
#          'poorest': 1,
#          'criteria': 1,
#          '1.2%3.0': 1,
#          'intermediate': 1,
#          '2.9%7.0': 1,
#          'case': 1,
#          'promoted': 1,
#          'broadly': 1,
#          'equivalent': 1,
#          'aqueous': 1,
#          'alcoholic': 1,
#          'nmol': 1,
#          'permit': 1,
#          'circulating': 1,
#          '100': 1,
#          'mumol': 1,
#          'voluminous': 1,
#          'literature': 1,
#          'anticancer': 1,
#          'antiinflammatory': 1,
#          'irrelevant': 1,
#          'absorbed': 1,
#          'c': 1,
#          '2003': 1,
#          'canadian': 1,
#          'society': 1,
#          'chemists': 1,
#          'rights': 1,
#          'reserved': 1,
#          'context': 1,
#          'distribution': 1,
#          'fraction': 1,
#          '83': 1,
#          '882': 1,
#          'adult': 1,
#          '27': 1,
#          '44': 1,
#          'second': 1,
#          '1991': 1,
#          'defined': 1,
#          'systolic': 1,
#          '120': 1,
#          'diastolic': 1,
#          '80': 1,
#          'score': 1,
#          'approaches': 1,
#          'responses': 1,
#          'food': 1,
#          'frequency': 1,
#          'supplemental': 1,
#          'combinations': 1,
#          'style': 1,
#          'avoidance': 1,
#          'supplementation': 1,
#          'attributable': 1,
#          '12': 1,
#          '319': 1,
#          'independently': 1,
#          'race': 1,
#          'family': 1,
#          'smoking': 1,
#          'oral': 1,
#          'contraceptives': 1,
#          '0.3': 1,
#          '0.22': 1,
#          '0.10': 1,
#          '78': 1,
#          '49%90': 1,
#          'lacked': 1,
#          'corresponding': 1,
#          'absolute': 1,
#          'difference': 1,
#          '8.37': 1,
#          '72': 1,
#          '57%82': 1,
#          '7.76': 1,
#          '0.8': 1,
#          '58': 1,
#          '46%67': 1,
#          '6.28': 1,
#          '1.6': 1,
#          '53': 1,
#          '45%60': 1,
#          '6.02': 1,
#          '3.1': 1,
#          'predictor': 1,
#          '38%41': 1,
#          'prevent': 1,
#          'proportion': 1,
#          'occurring': 1,
#          'young': 1,
#          'jama': 1,
#          '2009;302(4):401': 1,
#          '411': 1,
#          'mildly': 1,
#          'function': 1,
#          'general': 1,
#          'practice': 1,
#          'intensively': 1,
#          'common': 1,
#          'protocol': 1,
#          'substudies': 1,
#          'psychological': 1,
#          'sequelae': 1,
#          'clinicians': 1,
#          'reasons': 1,
#          'decision': 1,
#          'options': 1,
#          'detection': 1,
#          'fibrosis': 1,
#          'birmingham': 1,
#          'lambeth': 1,
#          'existing': 1,
#          'obvious': 1,
#          'interactions': 1,
#          'initial': 1,
#          'pattern': 1,
#          'autoimmune': 1,
#          'hepatitis': 1,
#          'haemochromatosis': 1,
#          'biliary': 1,
#          'metastatic': 1,
#          'hypothyroidism': 1,
#          'absence': 1,
#          'detectable': 1,
#          'fewer': 1,
#          'unlikely': 1,
#          'treatment': 1,
#          'largely': 1,
#          'subsumed': 1,
#          'alanine': 1,
#          'aminotransferase': 1,
#          'alkaline': 1,
#          'phosphatase': 1,
#          'gamma': 1,
#          'glutamyltransferase': 1,
#          'offers': 1,
#          'increase': 1,
#          'sensitivity': 1,
#          'margin': 1,
#          'cost': 1,
#          'specificity': 1,
#          'eighty': 1,
#          'cent': 1,
#          'remain': 1,
#          'retesting': 1,
#          'later': 1,
#          'carrying': 1,
#          'definitive': 1,
#          'view': 1,
#          'ultrasound': 1,
#          'reduced': 1,
#          'j': 1,
#          'shaped': 1,
#          'result': 1,
#          'temporary': 1,
#          'appear': 1,
#          'promote': 1,
#          'behaviour': 1,
#          'change': 1,
#          'rare': 1,
#          'helpful': 1,
#          'majority': 1,
#          'adds': 1,
#          'return': 1,
#          'false': 1,
#          'sensitive': 1,
#          'seldom': 1,
#          'revert': 1,
#          'modelling': 1,
#          'shows': 1,
#          'recommended': 1,
#          'guidelines': 1,
#          'inefficient': 1,
#          'undertaken': 1,
#          'meet': 1,
#          'perceived': 1,
#          'patient': 1,
#          'indicative': 1,
#          'suitable': 1,
#          'raised': 1,
#          'strong': 1,
#          'presumptive': 1,
#          'provoke': 1,
#          'short': 1,
#          'reduces': 1,
#          'work': 1,
#          'recommendations': 1,
#          'controls': 1,
#          'long': 1,
#          'predict': 1,
#          'hepatosteatosis': 1,
#          'acceptability': 1,
#          'replacing': 1,
#          'traditional': 1,
#          'six': 1,
#          'analyte': 1,
#          'drop': 1,
#          'menu': 1,
#          'combination': 1,
#          'examine': 1,
#          'completed': 1,
#          'supplementary': 1,
#          'professionals': 1,
#          '2004': 1,
#          'august': 1,
#          '2021': 1,
#          'exposures': 1,
#          'consisted': 1,
#          'nonsmoking': 1,
#          '18.5': 1,
#          'engaging': 1,
#          '150': 1,
#          'quality': 1,
#          '40th': 1,
#          'percentile': 1,
#          'alternative': 1,
#          'eating': 1,
#          '15': 1,
#          'outcomes': 1,
#          'physician': 1,
#          'diagnosed': 1,
#          'surveys': 1,
#          '7077': 1,
#          '4982': 1,
#          'nhs': 1,
#          '2095': 1,
#          'hpfs': 1,
#          'sd': 1,
#          '61': 1,
#          '8.8': 1,
#          '94.2': 1,
#          '2878': 1,
#          'developed': 1,
#          'multivariable': 1,
#          'adjustment': 1,
#          '0.73': 1,
#          '0.71': 1,
#          '0.54': 1,
#          '0.93': 1,
#          '0.76': 1,
#          '1.01': 1,
#          '0.42': 1,
#          '0.23': 1,
#          '0.79': 1,
#          '0.35': 1,
#          '0.68': 1,
#          '0.83': 1,
#          '0.67': 1,
#          '0.88': 1,
#          '0.65': 1,
#          '0.48': 1,
#          '0.34': 1,
#          '0.37': 1,
#          'addition': 1,
#          'improvement': 1,
#          'number': 1,
#          '6%(rr': 1,
#          '0.94': 1,
#          '9%(rr': 1,
#          '0.96': 1,
#          'stratified': 1,
#          'sex': 1,
#          'relevance': 1,
#          'adhering': 1,
#          'substantial': 1,
#          'reduction': 1,
#          'burden': 1,
#          'decrease': 1,
#          'hand': 1,
#          'comparison': 1,
#          'middle': 1,
#          'menopausal': 1,
#          'contraindications': 1,
#          'informed': 1,
#          'net': 1,
#          'benefits': 1,
#          'amounts': 1,
#          'inconsistent': 1,
#          'prospectively': 1,
#          'midlife': 1,
#          'drawn': 1,
#          '11,372': 1,
#          '1981': 1,
#          '2012': 1,
#          '601': 1,
#          '110': 1,
#          'deaths': 1,
#          'occurred': 1,
#          'weekly': 1,
#          'pair': 1,
#          'control': 1,
#          'confounding': 1,
#          'shared': 1,
#          'nonabstainers': 1,
#          '1.91': 1,
#          'confounders': 1,
#          '1.28': 1,
#          '1.06': 1,
#          '1.55': 1,
#          'abstainers': 1,
#          '3.47': 1,
#          'suggested': 1,
#          'abstinence': 1,
#          'scale': 1,
#          'extremely': 1,
#          '46,347': 1,
#          'japanese': 1,
#          '69': 1,
#          '1990': 1,
#          '1994': 1,
#          'hazards': 1,
#          'according': 1,
#          'year': 1,
#          'documented': 1,
#          '651': 1,
#          'confined': 1,
#          'occasional': 1,
#          '1.31': 1,
#          '0.89': 1,
#          '1.94': 1,
#          '0.58': 1,
#          '0.26': 1,
#          '0.49': 1,
#          '1.69': 1,
#          '2.72': 1,
#          '0.02': 1,
#          'variation': 1,
#          'inconsistently': 1,
#          'aim': 1,
#          'systematically': 1,
#          'cochrane': 1,
#          'library': 1,
#          'databases': 1,
#          'inception': 1,
#          '2017': 1,
#          'evaluating': 1,
#          'model': 1,
#          'involving': 1,
#          '22,545': 1,
#          '5,820,431': 1,
#          'furthermore': 1,
#          'regardless': 1,
#          'gender': 1,
#          'educational': 1,
#          'attainment': 1,
#          'play': 1,
#          'protective': 1,
#          'subgroups': 1,
#          'explore': 1,
#          'precise': 1,
#          'quantification': 1,
#          'preventing': 1,
#          'web': 1,
#          'science': 1,
#          'articles': 1,
#          'published': 1,
#          'december': 1,
#          '2016': 1,
#          '23': 1,
#          '5,886,792': 1,
#          'derived': 1,
#          'analytic': 1,
#          'taking': 1,
#          'account': 1,
#          'correlations': 1,
#          '1.17': 1,
#          '1.34': 1,
#          '79.6': 1,
#          '0.05': 1,
#          '7': 1,
#          '28.9': 1,
#          '0.002': 1,
#          'provides': 1,
#          'available': 1,
#          '1992': 1,
#          '2010': 1,
#          '477,325': 1,
#          'investigation': 1,
#          'nutrition': 1,
#          'n931': 1,
#          'estimated': 1,
#          'categories': 1,
#          'recruitment': 1,
#          '0.78': 1,
#          '0.82': 1,
#          '0.64': 1,
#          '0.70': 1,
#          '0.63': 1,
#          'respectively': 1,
#          'p(trend)0.001': 1,
#          'subsite': 1,
#          'hypertensive': 1,
#          'decreased': 1,
#          'previous': 1,
#          'involved': 1,
#          'etiology': 1,
#          '500,000': 1,
#          'authors': 1,
#          'established': 1,
#          'extensive': 1,
#          'topic': 1,
#          ...})

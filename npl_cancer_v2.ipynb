# %% [markdown]
# ## NPL Processing
# #### O seguinte arquivo usará NPL por meio da biblioteca 'spacy' para melhor entender os padrões dos abstracts dos artigos

# %%
# Importação de Bibliotecas 
import pandas as pd 
import spacy
from spacy import displacy
from nltk.tokenize import TreebankWordTokenizer

# %%
#constantes
t = TreebankWordTokenizer()
nlp = spacy.load('en_core_web_sm')
palavras_chave = ["alcohol", "cancer", "consumption","ethanol"]

# %% [markdown]
# #### Importar os artigos

# %%
df = pd.read_excel("df_completo.xlsx")

# %% [markdown]
# ### Filtro

# %%
artigos = df.iloc[0:1000]
abstracts = artigos["Abstract"].dropna()
index = abstracts.index

# %%
list_found_all = []

for texto, num in zip(abstracts, index):

    # Split the text into tokens
    tooks = nlp(texto)
    
    # Convert tokens to lowercase
    tooks_ = [t.lower_ for t in tooks]
    #print(tooks_)
    
    # Check if all words in palavras_chave are present in tooks_
    if all(word in tooks_ for word in palavras_chave):
        list_found_all.append(num)

    # If all keywords are found, this is a high-interest article 

# Print the articles that contain all keywords
print(f"Articles that contain all keywords (index): {list_found_all}")
# Out:
# Articles that contain all keywords (index): [433, 468, 489, 507, 529, 541, 558, 580, 583, 628, 717, 770, 782, 800, 806, 807, 825, 849, 882, 946, 959, 961, 967, 971, 987]

# %% [markdown]
# ### Tokenization
# #### Teste com um abstract

# %%
s = df['Abstract'][1]
print(s)
# Out:
# Plasma carotenoid responses were determined in 36 healthy men and women before and after being fed controlled diets with a moderate amount of fat (26% of total energy) and a high carotenoid content (approximate to 16 mg/d) for two 15-d periods. in addition, broccoli (205 g/d) was provided either during the first or the second 15-d residency period in a crossover design. Plasma was digested with lipase and cholesterol esterase, and carotenoids were extracted and measured by using HPLC. Three oxygenated carotenoids (lutein, zeaxanthin, and cryptoxanthin), three hydrocarbon carbon carotenoids (alpha-carotene, all-trans-beta-carotene, and 13-cis-beta-carotene), and four geometric isomers of lycopene (15-cis-, 13-cis-, 9-cis-, and all-trans-lycopene) were separated by using a C30 carotenoid column. A small unidentified peak coeluted with standard 9-cis-beta-carotene and was identified as zeta-carotene (lambda(max) = 400 nm). The concentrations of plasma lutein, cryptoxanthin, alpha-carotene, 13-cis-beta-carotene, all-trans-beta-carotene, and cis- and trans-lycopenes were all significantly increased (P < 0.05) on days 6-16 by the high-fruit and -vegetable diets. The provision of additional broccoli for 5 d to the bas ic high-carotenoid diet resulted in a further significant increase in the serum concentration of lutein compared with the feeding of the basic high-carotenoid diet alone. Most of the measurable carotenoids of human plasma can be increased by moderate alterations in diet within a short time, although the magnitude of the plasma response may be related to the baseline caratenoid concentrations.

# %%
doc = nlp(s)
print([sent for sent in doc.sents])
#print([(t.text, t.i) for t in doc.sents])
# Out:
# [Plasma carotenoid responses were determined in 36 healthy men and women before and after being fed controlled diets with a moderate amount of fat (26% of total energy) and a high carotenoid content (approximate to 16 mg/d) for two 15-d periods., in addition, broccoli (205 g/d) was provided either during the first or the second 15-d residency period in a crossover design., Plasma was digested with lipase and cholesterol esterase, and carotenoids were extracted and measured by using HPLC., Three oxygenated carotenoids (lutein, zeaxanthin, and cryptoxanthin), three hydrocarbon carbon carotenoids (alpha-carotene, all-trans-beta-carotene, and 13-cis-beta-carotene), and four geometric isomers of lycopene (15-cis-, 13-cis-, 9-cis-, and all-trans-lycopene) were separated by using a C30 carotenoid column., A small unidentified peak coeluted with standard 9-cis-beta-carotene and was identified as zeta-carotene (lambda(max) = 400 nm)., The concentrations of plasma lutein, cryptoxanthin, alpha-carotene, 13-cis-beta-carotene, all-trans-beta-carotene, and cis- and trans-lycopenes were all significantly increased (P < 0.05) on days 6-16 by the high-fruit and -vegetable diets., The provision of additional broccoli for 5 d to the bas ic high-carotenoid diet resulted in a further significant increase in the serum concentration of lutein compared with the feeding of the basic high-carotenoid diet alone., Most of the measurable carotenoids of human plasma can be increased by moderate alterations in diet within a short time, although the magnitude of the plasma response may be related to the baseline caratenoid concentrations.]

# %% [markdown]
# ### Pré-Processamento

# %% [markdown]
# #### Case-folding

# %%
print([t.lower_ if not t.is_sent_start else t for t in doc])
# Out:
# [Plasma, 'carotenoid', 'responses', 'were', 'determined', 'in', '36', 'healthy', 'men', 'and', 'women', 'before', 'and', 'after', 'being', 'fed', 'controlled', 'diets', 'with', 'a', 'moderate', 'amount', 'of', 'fat', '(', '26', '%', 'of', 'total', 'energy', ')', 'and', 'a', 'high', 'carotenoid', 'content', '(', 'approximate', 'to', '16', 'mg', '/', 'd', ')', 'for', 'two', '15', '-', 'd', 'periods', '.', in, 'addition', ',', 'broccoli', '(', '205', 'g', '/', 'd', ')', 'was', 'provided', 'either', 'during', 'the', 'first', 'or', 'the', 'second', '15', '-', 'd', 'residency', 'period', 'in', 'a', 'crossover', 'design', '.', Plasma, 'was', 'digested', 'with', 'lipase', 'and', 'cholesterol', 'esterase', ',', 'and', 'carotenoids', 'were', 'extracted', 'and', 'measured', 'by', 'using', 'hplc', '.', Three, 'oxygenated', 'carotenoids', '(', 'lutein', ',', 'zeaxanthin', ',', 'and', 'cryptoxanthin', ')', ',', 'three', 'hydrocarbon', 'carbon', 'carotenoids', '(', 'alpha', '-', 'carotene', ',', 'all', '-', 'trans', '-', 'beta', '-', 'carotene', ',', 'and', '13', '-', 'cis', '-', 'beta', '-', 'carotene', ')', ',', 'and', 'four', 'geometric', 'isomers', 'of', 'lycopene', '(', '15', '-', 'cis-', ',', '13', '-', 'cis-', ',', '9', '-', 'cis-', ',', 'and', 'all', '-', 'trans', '-', 'lycopene', ')', 'were', 'separated', 'by', 'using', 'a', 'c30', 'carotenoid', 'column', '.', A, 'small', 'unidentified', 'peak', 'coeluted', 'with', 'standard', '9', '-', 'cis', '-', 'beta', '-', 'carotene', 'and', 'was', 'identified', 'as', 'zeta', '-', 'carotene', '(', 'lambda(max', ')', '=', '400', 'nm', ')', '.', The, 'concentrations', 'of', 'plasma', 'lutein', ',', 'cryptoxanthin', ',', 'alpha', '-', 'carotene', ',', '13', '-', 'cis', '-', 'beta', '-', 'carotene', ',', 'all', '-', 'trans', '-', 'beta', '-', 'carotene', ',', 'and', 'cis-', 'and', 'trans', '-', 'lycopenes', 'were', 'all', 'significantly', 'increased', '(', 'p', '<', '0.05', ')', 'on', 'days', '6', '-', '16', 'by', 'the', 'high', '-', 'fruit', 'and', '-vegetable', 'diets', '.', The, 'provision', 'of', 'additional', 'broccoli', 'for', '5', 'd', 'to', 'the', 'bas', 'ic', 'high', '-', 'carotenoid', 'diet', 'resulted', 'in', 'a', 'further', 'significant', 'increase', 'in', 'the', 'serum', 'concentration', 'of', 'lutein', 'compared', 'with', 'the', 'feeding', 'of', 'the', 'basic', 'high', '-', 'carotenoid', 'diet', 'alone', '.', Most, 'of', 'the', 'measurable', 'carotenoids', 'of', 'human', 'plasma', 'can', 'be', 'increased', 'by', 'moderate', 'alterations', 'in', 'diet', 'within', 'a', 'short', 'time', ',', 'although', 'the', 'magnitude', 'of', 'the', 'plasma', 'response', 'may', 'be', 'related', 'to', 'the', 'baseline', 'caratenoid', 'concentrations', '.']

# %% [markdown]
# #### Stop Word Removal

# %% [markdown]
# ##### Utilizando o repertório de Stop Words do Spacy:

# %%
print([t for t in doc if not t.is_stop])
# Out:
# [Plasma, carotenoid, responses, determined, 36, healthy, men, women, fed, controlled, diets, moderate, fat, (, 26, %, total, energy, ), high, carotenoid, content, (, approximate, 16, mg, /, d, ), 15, -, d, periods, ., addition, ,, broccoli, (, 205, g, /, d, ), provided, second, 15, -, d, residency, period, crossover, design, ., Plasma, digested, lipase, cholesterol, esterase, ,, carotenoids, extracted, measured, HPLC, ., oxygenated, carotenoids, (, lutein, ,, zeaxanthin, ,, cryptoxanthin, ), ,, hydrocarbon, carbon, carotenoids, (, alpha, -, carotene, ,, -, trans, -, beta, -, carotene, ,, 13, -, cis, -, beta, -, carotene, ), ,, geometric, isomers, lycopene, (, 15, -, cis-, ,, 13, -, cis-, ,, 9, -, cis-, ,, -, trans, -, lycopene, ), separated, C30, carotenoid, column, ., small, unidentified, peak, coeluted, standard, 9, -, cis, -, beta, -, carotene, identified, zeta, -, carotene, (, lambda(max, ), =, 400, nm, ), ., concentrations, plasma, lutein, ,, cryptoxanthin, ,, alpha, -, carotene, ,, 13, -, cis, -, beta, -, carotene, ,, -, trans, -, beta, -, carotene, ,, cis-, trans, -, lycopenes, significantly, increased, (, P, <, 0.05, ), days, 6, -, 16, high, -, fruit, -vegetable, diets, ., provision, additional, broccoli, 5, d, bas, ic, high, -, carotenoid, diet, resulted, significant, increase, serum, concentration, lutein, compared, feeding, basic, high, -, carotenoid, diet, ., measurable, carotenoids, human, plasma, increased, moderate, alterations, diet, short, time, ,, magnitude, plasma, response, related, baseline, caratenoid, concentrations, .]

# %% [markdown]
# #### Lemmatization

# %% [markdown]
# ##### Aplicando _Lemmatization_ no abstract:

# %%
[(t.text, t.lemma_) for t in doc]
# Out:
# [('Plasma', 'plasma'),
#  ('carotenoid', 'carotenoid'),
#  ('responses', 'response'),
#  ('were', 'be'),
#  ('determined', 'determine'),
#  ('in', 'in'),
#  ('36', '36'),
#  ('healthy', 'healthy'),
#  ('men', 'man'),
#  ('and', 'and'),
#  ('women', 'woman'),
#  ('before', 'before'),
#  ('and', 'and'),
#  ('after', 'after'),
#  ('being', 'be'),
#  ('fed', 'feed'),
#  ('controlled', 'control'),
#  ('diets', 'diet'),
#  ('with', 'with'),
#  ('a', 'a'),
#  ('moderate', 'moderate'),
#  ('amount', 'amount'),
#  ('of', 'of'),
#  ('fat', 'fat'),
#  ('(', '('),
#  ('26', '26'),
#  ('%', '%'),
#  ('of', 'of'),
#  ('total', 'total'),
#  ('energy', 'energy'),
#  (')', ')'),
#  ('and', 'and'),
#  ('a', 'a'),
#  ('high', 'high'),
#  ('carotenoid', 'carotenoid'),
#  ('content', 'content'),
#  ('(', '('),
#  ('approximate', 'approximate'),
#  ('to', 'to'),
#  ('16', '16'),
#  ('mg', 'mg'),
#  ('/', '/'),
#  ('d', 'd'),
#  (')', ')'),
#  ('for', 'for'),
#  ('two', 'two'),
#  ('15', '15'),
#  ('-', '-'),
#  ('d', 'd'),
#  ('periods', 'period'),
#  ('.', '.'),
#  ('in', 'in'),
#  ('addition', 'addition'),
#  (',', ','),
#  ('broccoli', 'broccoli'),
#  ('(', '('),
#  ('205', '205'),
#  ('g', 'g'),
#  ('/', '/'),
#  ('d', 'd'),
#  (')', ')'),
#  ('was', 'be'),
#  ('provided', 'provide'),
#  ('either', 'either'),
#  ('during', 'during'),
#  ('the', 'the'),
#  ('first', 'first'),
#  ('or', 'or'),
#  ('the', 'the'),
#  ('second', 'second'),
#  ('15', '15'),
#  ('-', '-'),
#  ('d', 'd'),
#  ('residency', 'residency'),
#  ('period', 'period'),
#  ('in', 'in'),
#  ('a', 'a'),
#  ('crossover', 'crossover'),
#  ('design', 'design'),
#  ('.', '.'),
#  ('Plasma', 'Plasma'),
#  ('was', 'be'),
#  ('digested', 'digest'),
#  ('with', 'with'),
#  ('lipase', 'lipase'),
#  ('and', 'and'),
#  ('cholesterol', 'cholesterol'),
#  ('esterase', 'esterase'),
#  (',', ','),
#  ('and', 'and'),
#  ('carotenoids', 'carotenoid'),
#  ('were', 'be'),
#  ('extracted', 'extract'),
#  ('and', 'and'),
#  ('measured', 'measure'),
#  ('by', 'by'),
#  ('using', 'use'),
#  ('HPLC', 'HPLC'),
#  ('.', '.'),
#  ('Three', 'three'),
#  ('oxygenated', 'oxygenate'),
#  ('carotenoids', 'carotenoid'),
#  ('(', '('),
#  ('lutein', 'lutein'),
#  (',', ','),
#  ('zeaxanthin', 'zeaxanthin'),
#  (',', ','),
#  ('and', 'and'),
#  ('cryptoxanthin', 'cryptoxanthin'),
#  (')', ')'),
#  (',', ','),
#  ('three', 'three'),
#  ('hydrocarbon', 'hydrocarbon'),
#  ('carbon', 'carbon'),
#  ('carotenoids', 'carotenoids'),
#  ('(', '('),
#  ('alpha', 'alpha'),
#  ('-', '-'),
#  ('carotene', 'carotene'),
#  (',', ','),
#  ('all', 'all'),
#  ('-', '-'),
#  ('trans', 'trans'),
#  ('-', '-'),
#  ('beta', 'beta'),
#  ('-', '-'),
#  ('carotene', 'carotene'),
#  (',', ','),
#  ('and', 'and'),
#  ('13', '13'),
#  ('-', '-'),
#  ('cis', 'cis'),
#  ('-', '-'),
#  ('beta', 'beta'),
#  ('-', '-'),
#  ('carotene', 'carotene'),
#  (')', ')'),
#  (',', ','),
#  ('and', 'and'),
#  ('four', 'four'),
#  ('geometric', 'geometric'),
#  ('isomers', 'isomer'),
#  ('of', 'of'),
#  ('lycopene', 'lycopene'),
#  ('(', '('),
#  ('15', '15'),
#  ('-', '-'),
#  ('cis-', 'cis-'),
#  (',', ','),
#  ('13', '13'),
#  ('-', '-'),
#  ('cis-', 'cis-'),
#  (',', ','),
#  ('9', '9'),
#  ('-', '-'),
#  ('cis-', 'cis-'),
#  (',', ','),
#  ('and', 'and'),
#  ('all', 'all'),
#  ('-', '-'),
#  ('trans', 'trans'),
#  ('-', '-'),
#  ('lycopene', 'lycopene'),
#  (')', ')'),
#  ('were', 'be'),
#  ('separated', 'separate'),
#  ('by', 'by'),
#  ('using', 'use'),
#  ('a', 'a'),
#  ('C30', 'C30'),
#  ('carotenoid', 'carotenoid'),
#  ('column', 'column'),
#  ('.', '.'),
#  ('A', 'a'),
#  ('small', 'small'),
#  ('unidentified', 'unidentified'),
#  ('peak', 'peak'),
#  ('coeluted', 'coelute'),
#  ('with', 'with'),
#  ('standard', 'standard'),
#  ('9', '9'),
#  ('-', '-'),
#  ('cis', 'cis'),
#  ('-', '-'),
#  ('beta', 'beta'),
#  ('-', '-'),
#  ('carotene', 'carotene'),
#  ('and', 'and'),
#  ('was', 'be'),
#  ('identified', 'identify'),
#  ('as', 'as'),
#  ('zeta', 'zeta'),
#  ('-', '-'),
#  ('carotene', 'carotene'),
#  ('(', '('),
#  ('lambda(max', 'lambda(max'),
#  (')', ')'),
#  ('=', '='),
#  ('400', '400'),
#  ('nm', 'nm'),
#  (')', ')'),
#  ('.', '.'),
#  ('The', 'the'),
#  ('concentrations', 'concentration'),
#  ('of', 'of'),
#  ('plasma', 'plasma'),
#  ('lutein', 'lutein'),
#  (',', ','),
#  ('cryptoxanthin', 'cryptoxanthin'),
#  (',', ','),
#  ('alpha', 'alpha'),
#  ('-', '-'),
#  ('carotene', 'carotene'),
#  (',', ','),
#  ('13', '13'),
#  ('-', '-'),
#  ('cis', 'cis'),
#  ('-', '-'),
#  ('beta', 'beta'),
#  ('-', '-'),
#  ('carotene', 'carotene'),
#  (',', ','),
#  ('all', 'all'),
#  ('-', '-'),
#  ('trans', 'trans'),
#  ('-', '-'),
#  ('beta', 'beta'),
#  ('-', '-'),
#  ('carotene', 'carotene'),
#  (',', ','),
#  ('and', 'and'),
#  ('cis-', 'cis-'),
#  ('and', 'and'),
#  ('trans', 'tran'),
#  ('-', '-'),
#  ('lycopenes', 'lycopene'),
#  ('were', 'be'),
#  ('all', 'all'),
#  ('significantly', 'significantly'),
#  ('increased', 'increase'),
#  ('(', '('),
#  ('P', 'p'),
#  ('<', '<'),
#  ('0.05', '0.05'),
#  (')', ')'),
#  ('on', 'on'),
#  ('days', 'day'),
#  ('6', '6'),
#  ('-', '-'),
#  ('16', '16'),
#  ('by', 'by'),
#  ('the', 'the'),
#  ('high', 'high'),
#  ('-', '-'),
#  ('fruit', 'fruit'),
#  ('and', 'and'),
#  ('-vegetable', '-vegetable'),
#  ('diets', 'diet'),
#  ('.', '.'),
#  ('The', 'the'),
#  ('provision', 'provision'),
#  ('of', 'of'),
#  ('additional', 'additional'),
#  ('broccoli', 'broccoli'),
#  ('for', 'for'),
#  ('5', '5'),
#  ('d', 'd'),
#  ('to', 'to'),
#  ('the', 'the'),
#  ('bas', 'bas'),
#  ('ic', 'ic'),
#  ('high', 'high'),
#  ('-', '-'),
#  ('carotenoid', 'carotenoid'),
#  ('diet', 'diet'),
#  ('resulted', 'result'),
#  ('in', 'in'),
#  ('a', 'a'),
#  ('further', 'far'),
#  ('significant', 'significant'),
#  ('increase', 'increase'),
#  ('in', 'in'),
#  ('the', 'the'),
#  ('serum', 'serum'),
#  ('concentration', 'concentration'),
#  ('of', 'of'),
#  ('lutein', 'lutein'),
#  ('compared', 'compare'),
#  ('with', 'with'),
#  ('the', 'the'),
#  ('feeding', 'feeding'),
#  ('of', 'of'),
#  ('the', 'the'),
#  ('basic', 'basic'),
#  ('high', 'high'),
#  ('-', '-'),
#  ('carotenoid', 'carotenoid'),
#  ('diet', 'diet'),
#  ('alone', 'alone'),
#  ('.', '.'),
#  ('Most', 'Most'),
#  ('of', 'of'),
#  ('the', 'the'),
#  ('measurable', 'measurable'),
#  ('carotenoids', 'carotenoid'),
#  ('of', 'of'),
#  ('human', 'human'),
#  ('plasma', 'plasma'),
#  ('can', 'can'),
#  ('be', 'be'),
#  ('increased', 'increase'),
#  ('by', 'by'),
#  ('moderate', 'moderate'),
#  ('alterations', 'alteration'),
#  ('in', 'in'),
#  ('diet', 'diet'),
#  ('within', 'within'),
#  ('a', 'a'),
#  ('short', 'short'),
#  ('time', 'time'),
#  (',', ','),
#  ('although', 'although'),
#  ('the', 'the'),
#  ('magnitude', 'magnitude'),
#  ('of', 'of'),
#  ('the', 'the'),
#  ('plasma', 'plasma'),
#  ('response', 'response'),
#  ('may', 'may'),
#  ('be', 'be'),
#  ('related', 'relate'),
#  ('to', 'to'),
#  ('the', 'the'),
#  ('baseline', 'baseline'),
#  ('caratenoid', 'caratenoid'),
#  ('concentrations', 'concentration'),
#  ('.', '.')]

# %% [markdown]
# ### Part-of-Speech Tagging, Named Entity Recognition, e Parsing.

# %% [markdown]
# #### Part-of-Speech Tagging (POS)

# %% [markdown]
# ##### Aplicando POS com "tag" por ser melhor explicado

# %%
[(t.text, t.tag_) for t in doc]
# Out:
# [('Plasma', 'NN'),
#  ('carotenoid', 'NN'),
#  ('responses', 'NNS'),
#  ('were', 'VBD'),
#  ('determined', 'VBN'),
#  ('in', 'IN'),
#  ('36', 'CD'),
#  ('healthy', 'JJ'),
#  ('men', 'NNS'),
#  ('and', 'CC'),
#  ('women', 'NNS'),
#  ('before', 'RB'),
#  ('and', 'CC'),
#  ('after', 'IN'),
#  ('being', 'VBG'),
#  ('fed', 'VBN'),
#  ('controlled', 'VBN'),
#  ('diets', 'NNS'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('moderate', 'JJ'),
#  ('amount', 'NN'),
#  ('of', 'IN'),
#  ('fat', 'NN'),
#  ('(', '-LRB-'),
#  ('26', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('total', 'JJ'),
#  ('energy', 'NN'),
#  (')', '-RRB-'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('high', 'JJ'),
#  ('carotenoid', 'NN'),
#  ('content', 'NN'),
#  ('(', '-LRB-'),
#  ('approximate', 'JJ'),
#  ('to', 'IN'),
#  ('16', 'CD'),
#  ('mg', 'NNP'),
#  ('/', 'SYM'),
#  ('d', 'CD'),
#  (')', '-RRB-'),
#  ('for', 'IN'),
#  ('two', 'CD'),
#  ('15', 'CD'),
#  ('-', 'HYPH'),
#  ('d', 'NN'),
#  ('periods', 'NNS'),
#  ('.', '.'),
#  ('in', 'IN'),
#  ('addition', 'NN'),
#  (',', ','),
#  ('broccoli', 'NNS'),
#  ('(', '-LRB-'),
#  ('205', 'CD'),
#  ('g', 'NNP'),
#  ('/', 'SYM'),
#  ('d', 'NN'),
#  (')', '-RRB-'),
#  ('was', 'VBD'),
#  ('provided', 'VBN'),
#  ('either', 'CC'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('15', 'CD'),
#  ('-', 'HYPH'),
#  ('d', 'NN'),
#  ('residency', 'NN'),
#  ('period', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('crossover', 'NN'),
#  ('design', 'NN'),
#  ('.', '.'),
#  ('Plasma', 'NNP'),
#  ('was', 'VBD'),
#  ('digested', 'VBN'),
#  ('with', 'IN'),
#  ('lipase', 'NN'),
#  ('and', 'CC'),
#  ('cholesterol', 'NN'),
#  ('esterase', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('carotenoids', 'NNS'),
#  ('were', 'VBD'),
#  ('extracted', 'VBN'),
#  ('and', 'CC'),
#  ('measured', 'VBN'),
#  ('by', 'IN'),
#  ('using', 'VBG'),
#  ('HPLC', 'NNP'),
#  ('.', '.'),
#  ('Three', 'CD'),
#  ('oxygenated', 'VBN'),
#  ('carotenoids', 'NNS'),
#  ('(', '-LRB-'),
#  ('lutein', 'NN'),
#  (',', ','),
#  ('zeaxanthin', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('cryptoxanthin', 'NNP'),
#  (')', '-RRB-'),
#  (',', ','),
#  ('three', 'CD'),
#  ('hydrocarbon', 'NN'),
#  ('carbon', 'NN'),
#  ('carotenoids', 'NNP'),
#  ('(', '-LRB-'),
#  ('alpha', 'NNP'),
#  ('-', 'HYPH'),
#  ('carotene', 'NNP'),
#  (',', ','),
#  ('all', 'DT'),
#  ('-', 'HYPH'),
#  ('trans', 'JJ'),
#  ('-', 'JJ'),
#  ('beta', 'NN'),
#  ('-', 'HYPH'),
#  ('carotene', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('13', 'CD'),
#  ('-', 'HYPH'),
#  ('cis', 'NN'),
#  ('-', 'HYPH'),
#  ('beta', 'NN'),
#  ('-', 'HYPH'),
#  ('carotene', 'NN'),
#  (')', '-RRB-'),
#  (',', ','),
#  ('and', 'CC'),
#  ('four', 'CD'),
#  ('geometric', 'JJ'),
#  ('isomers', 'NNS'),
#  ('of', 'IN'),
#  ('lycopene', 'NN'),
#  ('(', '-LRB-'),
#  ('15', 'CD'),
#  ('-', 'HYPH'),
#  ('cis-', 'NN'),
#  (',', ','),
#  ('13', 'CD'),
#  ('-', 'HYPH'),
#  ('cis-', 'NN'),
#  (',', ','),
#  ('9', 'CD'),
#  ('-', 'HYPH'),
#  ('cis-', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('all', 'DT'),
#  ('-', 'HYPH'),
#  ('trans', 'JJ'),
#  ('-', 'NN'),
#  ('lycopene', 'JJ'),
#  (')', '-RRB-'),
#  ('were', 'VBD'),
#  ('separated', 'VBN'),
#  ('by', 'IN'),
#  ('using', 'VBG'),
#  ('a', 'DT'),
#  ('C30', 'NNP'),
#  ('carotenoid', 'NN'),
#  ('column', 'NN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('small', 'JJ'),
#  ('unidentified', 'JJ'),
#  ('peak', 'NN'),
#  ('coeluted', 'VBN'),
#  ('with', 'IN'),
#  ('standard', 'JJ'),
#  ('9', 'CD'),
#  ('-', 'HYPH'),
#  ('cis', 'NN'),
#  ('-', 'HYPH'),
#  ('beta', 'NN'),
#  ('-', 'HYPH'),
#  ('carotene', 'NN'),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('identified', 'VBN'),
#  ('as', 'IN'),
#  ('zeta', 'NN'),
#  ('-', 'HYPH'),
#  ('carotene', 'NNP'),
#  ('(', '-LRB-'),
#  ('lambda(max', 'NNP'),
#  (')', '-RRB-'),
#  ('=', 'VBZ'),
#  ('400', 'CD'),
#  ('nm', 'NNS'),
#  (')', '-RRB-'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('concentrations', 'NNS'),
#  ('of', 'IN'),
#  ('plasma', 'NNP'),
#  ('lutein', 'NNP'),
#  (',', ','),
#  ('cryptoxanthin', 'NNP'),
#  (',', ','),
#  ('alpha', 'NNP'),
#  ('-', 'HYPH'),
#  ('carotene', 'NNP'),
#  (',', ','),
#  ('13', 'CD'),
#  ('-', 'HYPH'),
#  ('cis', 'NN'),
#  ('-', 'HYPH'),
#  ('beta', 'NN'),
#  ('-', 'HYPH'),
#  ('carotene', 'NN'),
#  (',', ','),
#  ('all', 'DT'),
#  ('-', 'HYPH'),
#  ('trans', 'JJ'),
#  ('-', 'JJ'),
#  ('beta', 'NN'),
#  ('-', 'HYPH'),
#  ('carotene', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('cis-', 'XX'),
#  ('and', 'CC'),
#  ('trans', 'NNS'),
#  ('-', 'NNS'),
#  ('lycopenes', 'NNS'),
#  ('were', 'VBD'),
#  ('all', 'DT'),
#  ('significantly', 'RB'),
#  ('increased', 'VBN'),
#  ('(', '-LRB-'),
#  ('P', 'NN'),
#  ('<', 'XX'),
#  ('0.05', 'CD'),
#  (')', '-RRB-'),
#  ('on', 'IN'),
#  ('days', 'NNS'),
#  ('6', 'CD'),
#  ('-', 'SYM'),
#  ('16', 'CD'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('high', 'JJ'),
#  ('-', 'HYPH'),
#  ('fruit', 'NN'),
#  ('and', 'CC'),
#  ('-vegetable', 'JJ'),
#  ('diets', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('provision', 'NN'),
#  ('of', 'IN'),
#  ('additional', 'JJ'),
#  ('broccoli', 'NNS'),
#  ('for', 'IN'),
#  ('5', 'CD'),
#  ('d', 'NN'),
#  ('to', 'IN'),
#  ('the', 'DT'),
#  ('bas', 'NNP'),
#  ('ic', 'NNP'),
#  ('high', 'JJ'),
#  ('-', 'HYPH'),
#  ('carotenoid', 'NN'),
#  ('diet', 'NN'),
#  ('resulted', 'VBD'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('further', 'RB'),
#  ('significant', 'JJ'),
#  ('increase', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('serum', 'NN'),
#  ('concentration', 'NN'),
#  ('of', 'IN'),
#  ('lutein', 'NN'),
#  ('compared', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('feeding', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('basic', 'JJ'),
#  ('high', 'JJ'),
#  ('-', 'HYPH'),
#  ('carotenoid', 'NN'),
#  ('diet', 'NN'),
#  ('alone', 'RB'),
#  ('.', '.'),
#  ('Most', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('measurable', 'JJ'),
#  ('carotenoids', 'NNS'),
#  ('of', 'IN'),
#  ('human', 'JJ'),
#  ('plasma', 'NN'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('increased', 'VBN'),
#  ('by', 'IN'),
#  ('moderate', 'JJ'),
#  ('alterations', 'NNS'),
#  ('in', 'IN'),
#  ('diet', 'NN'),
#  ('within', 'IN'),
#  ('a', 'DT'),
#  ('short', 'JJ'),
#  ('time', 'NN'),
#  (',', ','),
#  ('although', 'IN'),
#  ('the', 'DT'),
#  ('magnitude', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('plasma', 'NN'),
#  ('response', 'NN'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('related', 'VBN'),
#  ('to', 'IN'),
#  ('the', 'DT'),
#  ('baseline', 'NN'),
#  ('caratenoid', 'NN'),
#  ('concentrations', 'NNS'),
#  ('.', '.')]

# %%
spacy.explain('NNS')
# Out:
# 'noun, plural'

# %% [markdown]
# #### Name Entity Recognition (NER)

# %% [markdown]
# ##### Aplicando NER com restrição de entidade:

# %%
print([(t.text, t.ent_type_) for t in doc if t.ent_type != 0])
# Out:
# [('Plasma', 'PERSON'), ('carotenoid', 'PERSON'), ('36', 'CARDINAL'), ('fed', 'ORG'), ('26', 'PERCENT'), ('%', 'PERCENT'), ('16', 'QUANTITY'), ('mg', 'QUANTITY'), ('/', 'QUANTITY'), ('two', 'CARDINAL'), ('15', 'CARDINAL'), ('205', 'CARDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('15', 'CARDINAL'), ('Plasma', 'PERSON'), ('HPLC', 'ORG'), ('Three', 'CARDINAL'), ('zeaxanthin', 'PERSON'), ('cryptoxanthin', 'PERSON'), ('three', 'CARDINAL'), ('13', 'QUANTITY'), ('-', 'QUANTITY'), ('cis', 'QUANTITY'), ('four', 'CARDINAL'), ('15', 'CARDINAL'), ('13', 'CARDINAL'), ('9', 'CARDINAL'), ('C30', 'PRODUCT'), ('9', 'QUANTITY'), ('-', 'QUANTITY'), ('cis', 'QUANTITY'), ('lambda(max', 'PERSON'), ('400', 'CARDINAL'), ('plasma', 'PERSON'), ('lutein', 'PERSON'), ('cryptoxanthin', 'PERSON'), ('13', 'QUANTITY'), ('-', 'QUANTITY'), ('cis', 'QUANTITY'), ('days', 'DATE'), ('6', 'DATE'), ('-', 'DATE'), ('16', 'DATE'), ('5', 'DATE'), ('d', 'DATE'), ('bas', 'PERSON')]

# %%
spacy.explain('PRODUCT') #investigar cada entity-type
# Out:
# 'Objects, vehicles, foods, etc. (not services)'

# %% [markdown]
# ##### Para melhor visualização utilizando NER:

# %%
print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# [('Plasma carotenoid', 'PERSON'), ('36', 'CARDINAL'), ('fed', 'ORG'), ('26%', 'PERCENT'), ('16 mg/', 'QUANTITY'), ('two', 'CARDINAL'), ('15', 'CARDINAL'), ('205', 'CARDINAL'), ('first', 'ORDINAL'), ('second', 'ORDINAL'), ('15', 'CARDINAL'), ('Plasma', 'PERSON'), ('HPLC', 'ORG'), ('Three', 'CARDINAL'), ('zeaxanthin', 'PERSON'), ('cryptoxanthin', 'PERSON'), ('three', 'CARDINAL'), ('13-cis', 'QUANTITY'), ('four', 'CARDINAL'), ('15', 'CARDINAL'), ('13', 'CARDINAL'), ('9', 'CARDINAL'), ('C30', 'PRODUCT'), ('9-cis', 'QUANTITY'), ('lambda(max', 'PERSON'), ('400', 'CARDINAL'), ('plasma lutein', 'PERSON'), ('cryptoxanthin', 'PERSON'), ('13-cis', 'QUANTITY'), ('days 6-16', 'DATE'), ('5 d', 'DATE'), ('bas', 'PERSON')]

# %%
print([(ent.text, ent.label_, ent.start_char, ent.end_char) for ent in doc.ents]) #visualizar posição
# Out:
# [('Plasma carotenoid', 'PERSON', 0, 17), ('36', 'CARDINAL', 47, 49), ('fed', 'ORG', 95, 98), ('26%', 'PERCENT', 147, 150), ('16 mg/', 'QUANTITY', 214, 220), ('two', 'CARDINAL', 227, 230), ('15', 'CARDINAL', 231, 233), ('205', 'CARDINAL', 268, 271), ('first', 'ORDINAL', 308, 313), ('second', 'ORDINAL', 321, 327), ('15', 'CARDINAL', 328, 330), ('Plasma', 'PERSON', 373, 379), ('HPLC', 'ORG', 484, 488), ('Three', 'CARDINAL', 490, 495), ('zeaxanthin', 'PERSON', 528, 538), ('cryptoxanthin', 'PERSON', 544, 557), ('three', 'CARDINAL', 560, 565), ('13-cis', 'QUANTITY', 643, 649), ('four', 'CARDINAL', 670, 674), ('15', 'CARDINAL', 706, 708), ('13', 'CARDINAL', 715, 717), ('9', 'CARDINAL', 724, 725), ('C30', 'PRODUCT', 782, 785), ('9-cis', 'QUANTITY', 854, 859), ('lambda(max', 'PERSON', 911, 921), ('400', 'CARDINAL', 925, 928), ('plasma lutein', 'PERSON', 956, 969), ('cryptoxanthin', 'PERSON', 971, 984), ('13-cis', 'QUANTITY', 1002, 1008), ('days 6-16', 'DATE', 1125, 1134), ('5 d', 'DATE', 1216, 1219), ('bas', 'PERSON', 1227, 1230)]

# %% [markdown]
# #### Visualização NER e PARSING:

# %% [markdown]
# ##### Utilizando "render" para visualizar o NER:

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plasma carotenoid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  responses were determined in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  healthy men and women before and after being
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  controlled diets with a moderate amount of fat (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     26%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of total energy) and a high carotenoid content (approximate to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16 mg/
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# d) for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -d periods. in addition, broccoli (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     205
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  g/d) was provided either during the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  or the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -d residency period in a crossover design.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plasma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was digested with lipase and cholesterol esterase, and carotenoids were extracted and measured by using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HPLC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  oxygenated carotenoids (lutein,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zeaxanthin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cryptoxanthin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ),
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  hydrocarbon carbon carotenoids (alpha-carotene, all-trans-beta-carotene, and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13-cis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# -beta-carotene), and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  geometric isomers of lycopene (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -cis-,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -cis-,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -cis-, and all-trans-lycopene) were separated by using a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  carotenoid column. A small unidentified peak coeluted with standard
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9-cis
#     <span style="font-size: 0.8em; font-weight: bold; lin

# %% [markdown]
# #### Parsing

# %% [markdown]
# ##### Utilizando o Parsing para melhor visualizar as relações entre as palavras:

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f5c7e75e8bc846d097c5e283ef33e933-0" class="displacy" width="45900" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Plasma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">carotenoid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">responses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">determined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">36</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">healthy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">men</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">women</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">before</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">being</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">fed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">controlled</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">diets</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">moderate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">amount</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">fat (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">26%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">total</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">energy)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">high</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor

# %%
[(t.text, t.dep_, t.head.text) for t in doc] #visualização das relações em texto
# Out:
# [('Plasma', 'compound', 'responses'),
#  ('carotenoid', 'compound', 'responses'),
#  ('responses', 'nsubjpass', 'determined'),
#  ('were', 'auxpass', 'determined'),
#  ('determined', 'ROOT', 'determined'),
#  ('in', 'prep', 'determined'),
#  ('36', 'nummod', 'men'),
#  ('healthy', 'amod', 'men'),
#  ('men', 'pobj', 'in'),
#  ('and', 'cc', 'men'),
#  ('women', 'conj', 'men'),
#  ('before', 'advmod', 'determined'),
#  ('and', 'cc', 'before'),
#  ('after', 'conj', 'before'),
#  ('being', 'auxpass', 'fed'),
#  ('fed', 'pcomp', 'after'),
#  ('controlled', 'amod', 'diets'),
#  ('diets', 'dobj', 'fed'),
#  ('with', 'prep', 'fed'),
#  ('a', 'det', 'amount'),
#  ('moderate', 'amod', 'amount'),
#  ('amount', 'pobj', 'with'),
#  ('of', 'prep', 'amount'),
#  ('fat', 'pobj', 'of'),
#  ('(', 'punct', '%'),
#  ('26', 'nummod', '%'),
#  ('%', 'appos', 'amount'),
#  ('of', 'prep', '%'),
#  ('total', 'amod', 'energy'),
#  ('energy', 'pobj', 'of'),
#  (')', 'punct', '%'),
#  ('and', 'cc', '%'),
#  ('a', 'det', 'content'),
#  ('high', 'amod', 'content'),
#  ('carotenoid', 'compound', 'content'),
#  ('content', 'conj', '%'),
#  ('(', 'punct', 'content'),
#  ('approximate', 'amod', 'content'),
#  ('to', 'prep', 'approximate'),
#  ('16', 'pobj', 'to'),
#  ('mg', 'pobj', 'to'),
#  ('/', 'punct', 'mg'),
#  ('d', 'appos', 'mg'),
#  (')', 'punct', 'mg'),
#  ('for', 'prep', 'content'),
#  ('two', 'nummod', 'periods'),
#  ('15', 'nummod', 'd'),
#  ('-', 'punct', 'd'),
#  ('d', 'compound', 'periods'),
#  ('periods', 'pobj', 'for'),
#  ('.', 'punct', 'determined'),
#  ('in', 'prep', 'provided'),
#  ('addition', 'pobj', 'in'),
#  (',', 'punct', 'provided'),
#  ('broccoli', 'nsubjpass', 'provided'),
#  ('(', 'punct', 'broccoli'),
#  ('205', 'nummod', 'g'),
#  ('g', 'appos', 'broccoli'),
#  ('/', 'punct', 'g'),
#  ('d', 'appos', 'g'),
#  (')', 'punct', 'g'),
#  ('was', 'auxpass', 'provided'),
#  ('provided', 'ROOT', 'provided'),
#  ('either', 'preconj', 'during'),
#  ('during', 'prep', 'provided'),
#  ('the', 'det', 'first'),
#  ('first', 'pobj', 'during'),
#  ('or', 'cc', 'first'),
#  ('the', 'det', 'period'),
#  ('second', 'amod', 'period'),
#  ('15', 'nummod', 'd'),
#  ('-', 'punct', 'd'),
#  ('d', 'compound', 'period'),
#  ('residency', 'compound', 'period'),
#  ('period', 'conj', 'first'),
#  ('in', 'prep', 'period'),
#  ('a', 'det', 'design'),
#  ('crossover', 'compound', 'design'),
#  ('design', 'pobj', 'in'),
#  ('.', 'punct', 'provided'),
#  ('Plasma', 'nsubjpass', 'digested'),
#  ('was', 'auxpass', 'digested'),
#  ('digested', 'ROOT', 'digested'),
#  ('with', 'prep', 'digested'),
#  ('lipase', 'nmod', 'esterase'),
#  ('and', 'cc', 'lipase'),
#  ('cholesterol', 'conj', 'lipase'),
#  ('esterase', 'pobj', 'with'),
#  (',', 'punct', 'digested'),
#  ('and', 'cc', 'digested'),
#  ('carotenoids', 'nsubjpass', 'extracted'),
#  ('were', 'auxpass', 'extracted'),
#  ('extracted', 'conj', 'digested'),
#  ('and', 'cc', 'extracted'),
#  ('measured', 'conj', 'extracted'),
#  ('by', 'prep', 'measured'),
#  ('using', 'pcomp', 'by'),
#  ('HPLC', 'dobj', 'using'),
#  ('.', 'punct', 'extracted'),
#  ('Three', 'nummod', 'carotenoids'),
#  ('oxygenated', 'amod', 'carotenoids'),
#  ('carotenoids', 'nsubjpass', 'separated'),
#  ('(', 'punct', 'carotenoids'),
#  ('lutein', 'appos', 'carotenoids'),
#  (',', 'punct', 'lutein'),
#  ('zeaxanthin', 'conj', 'lutein'),
#  (',', 'punct', 'zeaxanthin'),
#  ('and', 'cc', 'zeaxanthin'),
#  ('cryptoxanthin', 'conj', 'zeaxanthin'),
#  (')', 'punct', 'carotenoids'),
#  (',', 'punct', 'carotenoids'),
#  ('three', 'nummod', 'carotenoids'),
#  ('hydrocarbon', 'nmod', 'carotenoids'),
#  ('carbon', 'compound', 'carotenoids'),
#  ('carotenoids', 'nsubjpass', 'separated'),
#  ('(', 'punct', 'carotenoids'),
#  ('alpha', 'compound', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('carotene', 'nmod', 'carotene'),
#  (',', 'punct', 'carotene'),
#  ('all', 'advmod', 'trans'),
#  ('-', 'punct', 'trans'),
#  ('trans', 'conj', 'carotene'),
#  ('-', 'punct', 'trans'),
#  ('beta', 'compound', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('carotene', 'appos', 'carotenoids'),
#  (',', 'punct', 'carotenoids'),
#  ('and', 'cc', 'carotenoids'),
#  ('13', 'nummod', 'cis'),
#  ('-', 'punct', 'cis'),
#  ('cis', 'nmod', 'carotene'),
#  ('-', 'punct', 'beta'),
#  ('beta', 'compound', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('carotene', 'conj', 'carotenoids'),
#  (')', 'punct', 'carotenoids'),
#  (',', 'punct', 'carotenoids'),
#  ('and', 'cc', 'carotenoids'),
#  ('four', 'nummod', 'isomers'),
#  ('geometric', 'amod', 'isomers'),
#  ('isomers', 'conj', 'carotenoids'),
#  ('of', 'prep', 'isomers'),
#  ('lycopene', 'pobj', 'of'),
#  ('(', 'punct', 'lycopene'),
#  ('15', 'nummod', 'cis-'),
#  ('-', 'punct', 'cis-'),
#  ('cis-', 'appos', 'isomers'),
#  (',', 'punct', 'cis-'),
#  ('13', 'nummod', 'cis-'),
#  ('-', 'punct', 'cis-'),
#  ('cis-', 'conj', 'cis-'),
#  (',', 'punct', 'cis-'),
#  ('9', 'nummod', 'cis-'),
#  ('-', 'punct', 'cis-'),
#  ('cis-', 'conj', 'cis-'),
#  (',', 'punct', 'cis-'),
#  ('and', 'cc', 'cis-'),
#  ('all', 'det', 'trans'),
#  ('-', 'punct', 'trans'),
#  ('trans', 'conj', 'cis-'),
#  ('-', 'conj', 'cis-'),
#  ('lycopene', 'amod', 'cis-'),
#  (')', 'punct', 'isomers'),
#  ('were', 'auxpass', 'separated'),
#  ('separated', 'ROOT', 'separated'),
#  ('by', 'prep', 'separated'),
#  ('using', 'pcomp', 'by'),
#  ('a', 'det', 'column'),
#  ('C30', 'compound', 'column'),
#  ('carotenoid', 'compound', 'column'),
#  ('column', 'dobj', 'using'),
#  ('.', 'punct', 'separated'),
#  ('A', 'det', 'peak'),
#  ('small', 'amod', 'peak'),
#  ('unidentified', 'amod', 'peak'),
#  ('peak', 'nsubjpass', 'identified'),
#  ('coeluted', 'acl', 'peak'),
#  ('with', 'prep', 'coeluted'),
#  ('standard', 'amod', 'carotene'),
#  ('9', 'nummod', 'cis'),
#  ('-', 'punct', 'cis'),
#  ('cis', 'compound', 'carotene'),
#  ('-', 'punct', 'beta'),
#  ('beta', 'compound', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('carotene', 'pobj', 'with'),
#  ('and', 'cc', 'peak'),
#  ('was', 'auxpass', 'identified'),
#  ('identified', 'ROOT', 'identified'),
#  ('as', 'prep', 'identified'),
#  ('zeta', 'compound', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('carotene', 'pobj', 'as'),
#  ('(', 'punct', 'lambda(max'),
#  ('lambda(max', 'appos', 'carotene'),
#  (')', 'punct', 'lambda(max'),
#  ('=', 'advcl', 'identified'),
#  ('400', 'nummod', 'nm'),
#  ('nm', 'appos', 'peak'),
#  (')', 'punct', 'identified'),
#  ('.', 'punct', 'identified'),
#  ('The', 'det', 'concentrations'),
#  ('concentrations', 'nsubjpass', 'increased'),
#  ('of', 'prep', 'concentrations'),
#  ('plasma', 'compound', 'lutein'),
#  ('lutein', 'pobj', 'of'),
#  (',', 'punct', 'lutein'),
#  ('cryptoxanthin', 'conj', 'lutein'),
#  (',', 'punct', 'cryptoxanthin'),
#  ('alpha', 'compound', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('carotene', 'conj', 'cryptoxanthin'),
#  (',', 'punct', 'carotene'),
#  ('13', 'nummod', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('cis', 'nmod', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('beta', 'compound', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('carotene', 'conj', 'carotene'),
#  (',', 'punct', 'carotene'),
#  ('all', 'advmod', 'trans'),
#  ('-', 'punct', 'trans'),
#  ('trans', 'conj', 'carotene'),
#  ('-', 'punct', 'trans'),
#  ('beta', 'compound', 'carotene'),
#  ('-', 'punct', 'carotene'),
#  ('carotene', 'conj', 'carotene'),
#  (',', 'punct', 'carotene'),
#  ('and', 'cc', 'carotene'),
#  ('cis-', 'conj', 'carotene'),
#  ('and', 'cc', 'cis-'),
#  ('trans', 'conj', 'cis-'),
#  ('-', 'conj', 'cis-'),
#  ('lycopenes', 'pobj', 'of'),
#  ('were', 'auxpass', 'increased'),
#  ('all', 'advmod', 'increased'),
#  ('significantly', 'advmod', 'increased'),
#  ('increased', 'ROOT', 'increased'),
#  ('(', 'punct', 'P'),
#  ('P', 'npadvmod', 'increased'),
#  ('<', 'dep', 'P'),
#  ('0.05', 'nummod', 'P'),
#  (')', 'punct', 'P'),
#  ('on', 'prep', 'P'),
#  ('days', 'pobj', 'on'),
#  ('6', 'nummod', 'days'),
#  ('-', 'punct', '16'),
#  ('16', 'prep', '6'),
#  ('by', 'prep', 'increased'),
#  ('the', 'det', 'diets'),
#  ('high', 'amod', 'fruit'),
#  ('-', 'punct', 'fruit'),
#  ('fruit', 'nmod', 'diets'),
#  ('and', 'cc', 'fruit'),
#  ('-vegetable', 'conj', 'fruit'),
#  ('diets', 'pobj', 'by'),
#  ('.', 'punct', 'increased'),
#  ('The', 'det', 'provision'),
#  ('provision', 'nsubj', 'resulted'),
#  ('of', 'prep', 'provision'),
#  ('additional', 'amod', 'broccoli'),
#  ('broccoli', 'pobj', 'of'),
#  ('for', 'prep', 'provision'),
#  ('5', 'nummod', 'd'),
#  ('d', 'pobj', 'for'),
#  ('to', 'prep', 'd'),
#  ('the', 'det', 'bas'),
#  ('bas', 'pobj', 'to'),
#  ('ic', 'nmod', 'diet'),
#  ('high', 'amod', 'carotenoid'),
#  ('-', 'punct', 'carotenoid'),
#  ('carotenoid', 'compound', 'diet'),
#  ('diet', 'pobj', 'for'),
#  ('resulted', 'ROOT', 'resulted'),
#  ('in', 'prep', 'resulted'),
#  ('a', 'det', 'increase'),
#  ('further', 'advmod', 'significant'),
#  ('significant', 'amod', 'increase'),
#  ('increase', 'pobj', 'in'),
#  ('in', 'prep', 'increase'),
#  ('the', 'det', 'concentration'),
#  ('serum', 'compound', 'concentration'),
#  ('concentration', 'pobj', 'in'),
#  ('of', 'prep', 'concentration'),
#  ('lutein', 'pobj', 'of'),
#  ('compared', 'prep', 'resulted'),
#  ('with', 'prep', 'compared'),
#  ('the', 'det', 'feeding'),
#  ('feeding', 'pobj', 'with'),
#  ('of', 'prep', 'feeding'),
#  ('the', 'det', 'diet'),
#  ('basic', 'amod', 'diet'),
#  ('high', 'amod', 'carotenoid'),
#  ('-', 'punct', 'carotenoid'),
#  ('carotenoid', 'compound', 'diet'),
#  ('diet', 'pobj', 'of'),
#  ('alone', 'advmod', 'diet'),
#  ('.', 'punct', 'resulted'),
#  ('Most', 'nsubjpass', 'increased'),
#  ('of', 'prep', 'Most'),
#  ('the', 'det', 'carotenoids'),
#  ('measurable', 'amod', 'carotenoids'),
#  ('carotenoids', 'pobj', 'of'),
#  ('of', 'prep', 'carotenoids'),
#  ('human', 'amod', 'plasma'),
#  ('plasma', 'pobj', 'of'),
#  ('can', 'aux', 'increased'),
#  ('be', 'auxpass', 'increased'),
#  ('increased', 'ROOT', 'increased'),
#  ('by', 'agent', 'increased'),
#  ('moderate', 'amod', 'alterations'),
#  ('alterations', 'pobj', 'by'),
#  ('in', 'prep', 'alterations'),
#  ('diet', 'pobj', 'in'),
#  ('within', 'prep', 'increased'),
#  ('a', 'det', 'time'),
#  ('short', 'amod', 'time'),
#  ('time', 'pobj', 'within'),
#  (',', 'punct', 'increased'),
#  ('although', 'mark', 'related'),
#  ('the', 'det', 'magnitude'),
#  ('magnitude', 'nsubjpass', 'related'),
#  ('of', 'prep', 'magnitude'),
#  ('the', 'det', 'response'),
#  ('plasma', 'compound', 'response'),
#  ('response', 'pobj', 'of'),
#  ('may', 'aux', 'related'),
#  ('be', 'auxpass', 'related'),
#  ('related', 'advcl', 'increased'),
#  ('to', 'prep', 'related'),
#  ('the', 'det', 'concentrations'),
#  ('baseline', 'amod', 'concentrations'),
#  ('caratenoid', 'compound', 'concentrations'),
#  ('concentrations', 'pobj', 'to'),
#  ('.', 'punct', 'increased')]
